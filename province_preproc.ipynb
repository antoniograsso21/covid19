# %%
import time
import requests
import datetime
import pandas as pd

from util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None 

level = 'province'
path_data = './data'
path_csv = path_data + '/csv'
file_name_out_p = path_csv + '/covid19-' + level + '.csv'

# %%
# Define today, yesterday and day before yesterday dates
date_tday = datetime.date.today()
date_yday = Functions.get_previous_date(date_tday)
date_bf_yday = Functions.get_previous_date(date_yday)
date_tday, date_yday, date_bf_yday
# Out:
# (datetime.date(2020, 10, 27),
#  datetime.date(2020, 10, 26),
#  datetime.date(2020, 10, 25))

# %%
# Today url for regions file
url_tday = Functions.get_url_date(level, date_tday)
# Yesterday url for regions file
url_yday = Functions.get_url_date(level, date_yday)
# Day before yesterday url for regions file
url_bf_yday = Functions.get_url_date(level, date_bf_yday)

url_tday, url_yday, url_bf_yday
# Out:
# ('https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province-20201027.csv',
#  'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province-20201026.csv',
#  'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province-20201025.csv')

# %%
# Get csv files
try:
    # today and yesterday if today present
    df_raw_p_1 = pd.read_csv(url_tday)
    print('Dati odierni')
    df_raw_p_0 = pd.read_csv(url_yday)
    date_last = date_tday
except Exception as e:
    # yesterday and day before yesterday otherwise
    df_raw_p_1 = pd.read_csv(url_yday)
    df_raw_p_0 = pd.read_csv(url_bf_yday)
    date_last = date_yday
    print('Dati di ieri')
# Out:
# Dati odierni

# %%
# State S
df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 0    2020-10-27T17:00:00   ITA               1              Piemonte
# 1    2020-10-27T17:00:00   ITA               1              Piemonte
# 2    2020-10-27T17:00:00   ITA               1              Piemonte
# 3    2020-10-27T17:00:00   ITA               1              Piemonte
# 4    2020-10-27T17:00:00   ITA               1              Piemonte
# ..                   ...   ...             ...                   ...
# 144  2020-10-27T17:00:00   ITA               9               Toscana
# 145  2020-10-27T17:00:00   ITA               4           P.A. Trento
# 146  2020-10-27T17:00:00   ITA              10                Umbria
# 147  2020-10-27T17:00:00   ITA               2         Valle d'Aosta
# 148  2020-10-27T17:00:00   ITA               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#            lat      long  totale_casi  note
# 0    45.073274  7.680687        31305   NaN
# 1    45.323981  8.423234         2362   NaN
# 2    45.445885  8.621916         4968   NaN
# 3    44.393296  7.551172         7345   NaN
# 4    44.899129  8.204143         3030   NaN
# ..         ...       ...          ...   ...
# 144        NaN       NaN            0   NaN
# 145        NaN       NaN            0   NaN
# 146        NaN       NaN            0   NaN
# 147        NaN       NaN            0   NaN
# 148        NaN       NaN          204   NaN
#
# [149 rows x 11 columns]

# %%
# State S - 1
df_raw_p_0.sort_values(by='codice_regione').reset_index(drop=True)
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 0    2020-10-26T17:00:00   ITA               1              Piemonte
# 1    2020-10-26T17:00:00   ITA               1              Piemonte
# 2    2020-10-26T17:00:00   ITA               1              Piemonte
# 3    2020-10-26T17:00:00   ITA               1              Piemonte
# 4    2020-10-26T17:00:00   ITA               1              Piemonte
# ..                   ...   ...             ...                   ...
# 144  2020-10-26T17:00:00   ITA              20              Sardegna
# 145  2020-10-26T17:00:00   ITA              20              Sardegna
# 146  2020-10-26T17:00:00   ITA              20              Sardegna
# 147  2020-10-26T17:00:00   ITA              20              Sardegna
# 148  2020-10-26T17:00:00   ITA              20              Sardegna
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   5                                  Asti              AT
# 1                 891    Fuori Regione / Provincia Autonoma             NaN
# 2                 103                  Verbano-Cusio-Ossola              VB
# 3                  96                                Biella              BI
# 4                 991  In fase di definizione/aggiornamento             NaN
# ..                ...                                   ...             ...
# 144               111                          Sud Sardegna              SU
# 145                95                              Oristano              OR
# 146                92                              Cagliari              CA
# 147                91                                 Nuoro              NU
# 148                90                               Sassari              SS
#
#            lat      long  totale_casi  note
# 0    44.899129  8.204143         2968   NaN
# 1          NaN       NaN          414   NaN
# 2    45.921445  8.551079         1648   NaN
# 3    45.566511  8.054082         1897   NaN
# 4          NaN       NaN          546   NaN
# ..         ...       ...          ...   ...
# 144  39.166415  8.526243         1246   NaN
# 145  39.903811  8.591183          655   NaN
# 146  39.215312  9.110616         1463   NaN
# 147  40.323188  9.330296         1133   NaN
# 148  40.726677  8.559667         3493   NaN
#
# [149 rows x 11 columns]

# %%
# Print raw columns
# print(df_raw_p_1.columns, df_raw_p_0.columns)
# Drop useless columns
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pf_1 = df_raw_p_1.drop(cols_to_drop, axis=1).sort_values(by='codice_provincia').reset_index(drop=True)
df_pf_0 = df_raw_p_0.drop(cols_to_drop, axis=1).sort_values(by='codice_provincia').reset_index(drop=True)
# df_pf_1.columns, df_pf_0.columns

# %%
df_p = df_pf_1.copy()
df_p['variazione_totale_casi'] = df_pf_1['totale_casi'] - df_pf_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2020-10-27T17:00:00               1              Piemonte
# 1    2020-10-27T17:00:00               1              Piemonte
# 2    2020-10-27T17:00:00               1              Piemonte
# 3    2020-10-27T17:00:00               1              Piemonte
# 4    2020-10-27T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2020-10-27T17:00:00               9               Toscana
# 145  2020-10-27T17:00:00               4           P.A. Trento
# 146  2020-10-27T17:00:00              10                Umbria
# 147  2020-10-27T17:00:00               2         Valle d'Aosta
# 148  2020-10-27T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi  variazione_totale_casi
# 0          31305                    1490
# 1           2362                      48
# 2           4968                     135
# 3           7345                     424
# 4           3030                      62
# ..           ...                     ...
# 144            0                       0
# 145            0                       0
# 146            0                       0
# 147            0                       0
# 148          204                      12
#
# [149 rows x 8 columns]

# %%
df_p.to_csv(file_name_out_p, index=False)
