# %%
import sys
import io
import time
import requests
import datetime
import numpy as np
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F
from src.util.pandas_wrapper import DataFrameWrapper

# Disable warning
pd.options.mode.chained_assignment = None 

# Open data file name
file_name_vaccine_administration_summary = 'somministrazioni-vaccini-summary-latest'
path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv/vaccine'

csv_out_name = f'{path_csv}/riepilogo-somministrazioni.csv'

# %%
url_vaccine_administration_summary = F.url_vaccine(file_name_vaccine_administration_summary)
url_vaccine_administration_summary
# Out:
# 'https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-summary-latest.csv'

# %%
df_vaccine_administration_summary_raw = pd.read_csv(url_vaccine_administration_summary)
df_vaccine_administration_summary_raw
# Out:
#      data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 0               2021-02-01  PIE    8638            3052             5586
# 1               2021-02-01  UMB    1260             333              927
# 2               2021-01-17  ABR     187              59              128
# 3               2021-01-08  LIG    2685             927             1758
# 4               2020-12-31  LOM     713             300              413
# ...                    ...  ...     ...             ...              ...
# 1122            2021-01-26  PAT     497             138              359
# 1123            2021-01-11  ABR    1551             557              994
# 1124            2021-01-26  PUG    5359            2397             2962
# 1125            2020-12-31  TOS     805             202              603
# 1126            2020-12-30  PUG       1               0                1
#
#       categoria_operatori_sanitari_sociosanitari  \
# 0                                           6162
# 1                                            876
# 2                                            136
# 3                                           1952
# 4                                            656
# ...                                          ...
# 1122                                         397
# 1123                                        1337
# 1124                                        4846
# 1125                                          97
# 1126                                           1
#
#       categoria_personale_non_sanitario  categoria_ospiti_rsa  \
# 0                                  1402                  1074
# 1                                    32                   352
# 2                                    51                     0
# 3                                   388                   345
# 4                                    57                     0
# ...                                 ...                   ...
# 1122                                 16                    84
# 1123                                166                    48
# 1124                                281                   232
# 1125                                 10                   698
# 1126                                  0                     0
#
#       categoria_over80  prima_dose  seconda_dose codice_NUTS1 codice_NUTS2  \
# 0                    0         578          8060          ITC         ITC1
# 1                    0          47          1213          ITI         ITI2
# 2                    0         180             7          ITF         ITF1
# 3                    0        2685             0          ITC         ITC3
# 4                    0         713             0          ITC         ITC4
# ...                ...         ...           ...          ...          ...
# 1122                 0          25           472          ITH         ITH2
# 1123                 0        1551             0          ITF         ITF1
# 1124                 0         574          4785          ITF         ITF4
# 1125                 0         805             0          ITI         ITI1
# 1126                 0           1             0          ITF         ITF4
#
#       codice_regione_ISTAT                  nome_area
# 0                        1                   Piemonte
# 1                       10                     Umbria
# 2                       13                    Abruzzo
# 3                        7                    Liguria
# 4                        3                  Lombardia
# ...                    ...                        ...
# 1122                     4  Provincia Autonoma Trento
# 1123                    13                    Abruzzo
# 1124                    16                     Puglia
# 1125                     9                    Toscana
# 1126                    16                     Puglia
#
# [1127 rows x 15 columns]

# %%
vaccine_administration_summary_wrapper = DataFrameWrapper(df_vaccine_administration_summary_raw.copy())
vaccine_administration_summary_wrapper.df;

# %%
# Headers names to lowercase
vaccine_administration_summary_wrapper.header_columns_lower()
list(vaccine_administration_summary_wrapper.df.columns)
# Out:
# ['data_somministrazione',
#  'area',
#  'totale',
#  'sesso_maschile',
#  'sesso_femminile',
#  'categoria_operatori_sanitari_sociosanitari',
#  'categoria_personale_non_sanitario',
#  'categoria_ospiti_rsa',
#  'categoria_over80',
#  'prima_dose',
#  'seconda_dose',
#  'codice_nuts1',
#  'codice_nuts2',
#  'codice_regione_istat',
#  'nome_area']

# %%
column_name_istat_code = 'codice_regione_istat'
column_name_area = 'area'
area_bolzano_name = 'PAB'
area_trento_name = 'PAT'
# Change istat code for trentino-alto adige provinces, TODO: function to edit dataframe values
vaccine_administration_summary_wrapper.change_column_value(column_name_area, area_bolzano_name, column_name_istat_code, 21)
vaccine_administration_summary_wrapper.change_column_value(column_name_area, area_trento_name, column_name_istat_code, 22)
vaccine_administration_summary_wrapper.df[(vaccine_administration_summary_wrapper.df.area == 'PAT') | (vaccine_administration_summary_wrapper.df.area == 'PAB')]
# Out:
#      data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 5               2021-01-21  PAT     349              93              256
# 7               2021-01-04  PAB     469             191              278
# 16              2021-01-30  PAT     383             130              253
# 18              2021-02-20  PAB    1502             471             1031
# 47              2021-01-07  PAB     892             317              575
# ...                    ...  ...     ...             ...              ...
# 1074            2021-01-29  PAB    1487             508              979
# 1084            2021-02-10  PAB    1622             600             1022
# 1088            2021-01-01  PAB       1               1                0
# 1117            2020-12-30  PAT       6               2                4
# 1122            2021-01-26  PAT     497             138              359
#
#       categoria_operatori_sanitari_sociosanitari  \
# 5                                            318
# 7                                            397
# 16                                           345
# 18                                           196
# 47                                           613
# ...                                          ...
# 1074                                         855
# 1084                                         484
# 1088                                           1
# 1117                                           4
# 1122                                         397
#
#       categoria_personale_non_sanitario  categoria_ospiti_rsa  \
# 5                                    15                    16
# 7                                    72                     0
# 16                                    7                    31
# 18                                  813                    24
# 47                                  227                     0
# ...                                 ...                   ...
# 1074                                335                   295
# 1084                                556                     1
# 1088                                  0                     0
# 1117                                  1                     1
# 1122                                 16                    84
#
#       categoria_over80  prima_dose  seconda_dose codice_nuts1 codice_nuts2  \
# 5                    0         227           122          ITH         ITH2
# 7                    0         469             0          ITH         ITH1
# 16                   0         151           232          ITH         ITH2
# 18                 469        1484            18          ITH         ITH1
# 47                  52         892             0          ITH         ITH1
# ...                ...         ...           ...          ...          ...
# 1074                 2          23          1464          ITH         ITH1
# 1084               581          26          1596          ITH         ITH1
# 1088                 0           1             0          ITH         ITH1
# 1117                 0           6             0          ITH         ITH2
# 1122                 0          25           472          ITH         ITH2
#
#       codice_regione_istat                           nome_area
# 5                       22           Provincia Autonoma Trento
# 7                       21  Provincia Autonoma Bolzano / Bozen
# 16                      22           Provincia Autonoma Trento
# 18                      21  Provincia Autonoma Bolzano / Bozen
# 47                      21  Provincia Autonoma Bolzano / Bozen
# ...                    ...                                 ...
# 1074                    21  Provincia Autonoma Bolzano / Bozen
# 1084                    21  Provincia Autonoma Bolzano / Bozen
# 1088                    21  Provincia Autonoma Bolzano / Bozen
# 1117                    22           Provincia Autonoma Trento
# 1122                    22           Provincia Autonoma Trento
#
# [106 rows x 15 columns]
