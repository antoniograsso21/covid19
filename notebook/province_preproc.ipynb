# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 38557  2020-11-25T17:00:00               5                Veneto
# 38558  2020-11-25T17:00:00               5                Veneto
# 38559  2020-11-25T17:00:00               5                Veneto
# 38560  2020-11-25T17:00:00               5                Veneto
# 38561  2020-11-25T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 38557                27                               Venezia              VE
# 38558                28                                Padova              PD
# 38559                29                                Rovigo              RO
# 38560               899    Fuori Regione / Provincia Autonoma             NaN
# 38561               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 38557        18892
# 38558        24780
# 38559         3547
# 38560         2251
# 38561          321
#
# [38562 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2020-11-25', '2020-11-24')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 38413  2020-11-25T17:00:00              13               Abruzzo
# 38414  2020-11-25T17:00:00              13               Abruzzo
# 38415  2020-11-25T17:00:00              13               Abruzzo
# 38416  2020-11-25T17:00:00              13               Abruzzo
# 38417  2020-11-25T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 38557  2020-11-25T17:00:00               5                Veneto
# 38558  2020-11-25T17:00:00               5                Veneto
# 38559  2020-11-25T17:00:00               5                Veneto
# 38560  2020-11-25T17:00:00               5                Veneto
# 38561  2020-11-25T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 38413                66                              L'Aquila              AQ
# 38414                67                                Teramo              TE
# 38415                68                               Pescara              PE
# 38416                69                                Chieti              CH
# 38417               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 38557                27                               Venezia              VE
# 38558                28                                Padova              PD
# 38559                29                                Rovigo              RO
# 38560               899    Fuori Regione / Provincia Autonoma             NaN
# 38561               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 38413         8234
# 38414         6779
# 38415         5108
# 38416         4901
# 38417          224
# ...            ...
# 38557        18892
# 38558        24780
# 38559         3547
# 38560         2251
# 38561          321
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 38264  2020-11-24T17:00:00              13               Abruzzo
# 38265  2020-11-24T17:00:00              13               Abruzzo
# 38266  2020-11-24T17:00:00              13               Abruzzo
# 38267  2020-11-24T17:00:00              13               Abruzzo
# 38268  2020-11-24T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 38408  2020-11-24T17:00:00               5                Veneto
# 38409  2020-11-24T17:00:00               5                Veneto
# 38410  2020-11-24T17:00:00               5                Veneto
# 38411  2020-11-24T17:00:00               5                Veneto
# 38412  2020-11-24T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#