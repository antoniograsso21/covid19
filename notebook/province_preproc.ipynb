# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 45560  2021-01-11T17:00:00               5                Veneto
# 45561  2021-01-11T17:00:00               5                Veneto
# 45562  2021-01-11T17:00:00               5                Veneto
# 45563  2021-01-11T17:00:00               5                Veneto
# 45564  2021-01-11T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 45560                27                               Venezia              VE
# 45561                28                                Padova              PD
# 45562                29                                Rovigo              RO
# 45563               899    Fuori Regione / Provincia Autonoma             NaN
# 45564               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 45560        45182
# 45561        52483
# 45562         8749
# 45563         3846
# 45564          579
#
# [45565 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-01-11', '2021-01-10')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 45416  2021-01-11T17:00:00              13               Abruzzo
# 45417  2021-01-11T17:00:00              13               Abruzzo
# 45418  2021-01-11T17:00:00              13               Abruzzo
# 45419  2021-01-11T17:00:00              13               Abruzzo
# 45420  2021-01-11T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 45560  2021-01-11T17:00:00               5                Veneto
# 45561  2021-01-11T17:00:00               5                Veneto
# 45562  2021-01-11T17:00:00               5                Veneto
# 45563  2021-01-11T17:00:00               5                Veneto
# 45564  2021-01-11T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 45416                66                              L'Aquila              AQ
# 45417                67                                Teramo              TE
# 45418                68                               Pescara              PE
# 45419                69                                Chieti              CH
# 45420               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 45560                27                               Venezia              VE
# 45561                28                                Padova              PD
# 45562                29                                Rovigo              RO
# 45563               899    Fuori Regione / Provincia Autonoma             NaN
# 45564               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 45416        11499
# 45417        10061
# 45418         7635
# 45419         8196
# 45420          316
# ...            ...
# 45560        45182
# 45561        52483
# 45562         8749
# 45563         3846
# 45564          579
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 45267  2021-01-10T17:00:00              13               Abruzzo
# 45268  2021-01-10T17:00:00              13               Abruzzo
# 45269  2021-01-10T17:00:00              13               Abruzzo
# 45270  2021-01-10T17:00:00              13               Abruzzo
# 45271  2021-01-10T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 45411  2021-01-10T17:00:00               5                Veneto
# 45412  2021-01-10T17:00:00               5                Veneto
# 45413  2021-01-10T17:00:00               5                Veneto
# 45414  2021-01-10T17:00:00               5                Veneto
# 45415  2021-01-10T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 45267                66                              L'Aquila              AQ
# 45268                67                                Teramo              TE
# 45269                68                               Pescara              PE
# 45270                69                                Chieti              CH
# 45271               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 45411                27                               Venezia              VE
# 45412                28                                Padova              PD
# 45413                29                                Rovigo              RO
# 45414               899    Fuori Regione / Provincia Autonoma             NaN
# 45415               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 45267        11486
# 45268        10036
# 45269         7605
# 45270         8145
# 45271          314
# ...            ...
# 45411        44860
# 45412        51969
# 45413         8703
# 45414         3835
# 45415          579
#
# [149 rows x 7 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-11T17:00:00               1              Piemonte
# 1    2021-01-11T17:00:00               1              Piemonte
# 2    2021-01-11T17:00:00               1              Piemonte
# 3    2021-01-11T17:00:00               1              Piemonte
# 4    2021-01-11T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-11T17:00:00               9               Toscana
# 145  2021-01-11T17:00:00               4           P.A. Trento
# 146  2021-01-11T17:00:00              10                Umbria
# 147  2021-01-11T17:00:00               2         Valle d'Aosta
# 148  2021-01-11T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         108648
# 1           7870
# 2          16288
# 3          28669
# 4          10653
# ..           ...
# 144            0
# 145            0
# 146            0
# 147            8
# 148          579
#
# [149 rows x 7 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-10T17:00:00               1              Piemonte
# 1    2021-01-10T17:00:00               1              Piemonte
# 2    2021-01-10T17:00:00               1              Piemonte
# 3    2021-01-10T17:00:00               1              Piemonte
# 4    2021-01-10T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-10T17:00:00               9               Toscana
# 145  2021-01-10T17:00:00               4           P.A. Trento
# 146  2021-01-10T17:00:00              10                Umbria
# 147  2021-01-10T17:00:00               2         Valle d'Aosta
# 148  2021-01-10T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         108285
# 1           7861
# 2          16270
# 3          28612
# 4          10613
# ..           ...
# 144            0
# 145            0
# 146            0
# 147            8
# 148          579
#
# [149 rows x 7 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-11T17:00:00               1              Piemonte
# 1    2021-01-11T17:00:00               1              Piemonte
# 2    2021-01-11T17:00:00               1              Piemonte
# 3    2021-01-11T17:00:00               1              Piemonte
# 4    2021-01-11T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-11T17:00:00               9               Toscana
# 145  2021-01-11T17:00:00               4           P.A. Trento
# 146  2021-01-11T17:00:00              10                Umbria
# 147  2021-01-11T17:00:00               2         Valle d'Aosta
# 148  2021-01-11T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi  variazione_totale_casi
# 0         108648                     363
# 1           7870                       9
# 2          16288                      18
# 3          28669                      57
# 4          10653                      40
# ..           ...                     ...
# 144            0                       0
# 145            0                       0
# 146            0                       0
# 147            8                       0
# 148          579                       0
#
# [149 rows x 8 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
