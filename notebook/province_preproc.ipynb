# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 38855  2020-11-27T17:00:00               5                Veneto
# 38856  2020-11-27T17:00:00               5                Veneto
# 38857  2020-11-27T17:00:00               5                Veneto
# 38858  2020-11-27T17:00:00               5                Veneto
# 38859  2020-11-27T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 38855                27                               Venezia              VE
# 38856                28                                Padova              PD
# 38857                29                                Rovigo              RO
# 38858               899    Fuori Regione / Provincia Autonoma             NaN
# 38859               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 38855        19809
# 38856        26072
# 38857         3713
# 38858         2349
# 38859          341
#
# [38860 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2020-11-27', '2020-11-26')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 38711  2020-11-27T17:00:00              13               Abruzzo
# 38712  2020-11-27T17:00:00              13               Abruzzo
# 38713  2020-11-27T17:00:00              13               Abruzzo
# 38714  2020-11-27T17:00:00              13               Abruzzo
# 38715  2020-11-27T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 38855  2020-11-27T17:00:00               5                Veneto
# 38856  2020-11-27T17:00:00               5                Veneto
# 38857  2020-11-27T17:00:00               5                Veneto
# 38858  2020-11-27T17:00:00               5                Veneto
# 38859  2020-11-27T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 38711                66                              L'Aquila              AQ
# 38712                67                                Teramo              TE
# 38713                68                               Pescara              PE
# 38714                69                                Chieti              CH
# 38715               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 38855                27                               Venezia              VE
# 38856                28                                Padova              PD
# 38857                29                                Rovigo              RO
# 38858               899    Fuori Regione / Provincia Autonoma             NaN
# 38859               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 38711         8633
# 38712         6938
# 38713         5446
# 38714         5098
# 38715          243
# ...            ...
# 38855        19809
# 38856        26072
# 38857         3713
# 38858         2349
# 38859          341
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 38562  2020-11-26T17:00:00              13               Abruzzo
# 38563  2020-11-26T17:00:00              13               Abruzzo
# 38564  2020-11-26T17:00:00              13               Abruzzo
# 38565  2020-11-26T17:00:00              13               Abruzzo
# 38566  2020-11-26T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 38706  2020-11-26T17:00:00               5                Veneto
# 38707  2020-11-26T17:00:00               5                Veneto
# 38708  2020-11-26T17:00:00               5                Veneto
# 38709  2020-11-26T17:00:00               5                Veneto
# 38710  2020-11-26T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#