# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 42729  2020-12-23T17:00:00               5                Veneto
# 42730  2020-12-23T17:00:00               5                Veneto
# 42731  2020-12-23T17:00:00               5                Veneto
# 42732  2020-12-23T17:00:00               5                Veneto
# 42733  2020-12-23T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 42729                27                               Venezia              VE
# 42730                28                                Padova              PD
# 42731                29                                Rovigo              RO
# 42732               899    Fuori Regione / Provincia Autonoma             NaN
# 42733               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 42729        33728
# 42730        41365
# 42731         6527
# 42732         3316
# 42733          491
#
# [42734 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2020-12-23', '2020-12-22')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 42585  2020-12-23T17:00:00              13               Abruzzo
# 42586  2020-12-23T17:00:00              13               Abruzzo
# 42587  2020-12-23T17:00:00              13               Abruzzo
# 42588  2020-12-23T17:00:00              13               Abruzzo
# 42589  2020-12-23T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 42729  2020-12-23T17:00:00               5                Veneto
# 42730  2020-12-23T17:00:00               5                Veneto
# 42731  2020-12-23T17:00:00               5                Veneto
# 42732  2020-12-23T17:00:00               5                Veneto
# 42733  2020-12-23T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 42585                66                              L'Aquila              AQ
# 42586                67                                Teramo              TE
# 42587                68                               Pescara              PE
# 42588                69                                Chieti              CH
# 42589               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 42729                27                               Venezia              VE
# 42730                28                                Padova              PD
# 42731                29                                Rovigo              RO
# 42732               899    Fuori Regione / Provincia Autonoma             NaN
# 42733               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 42585        10669
# 42586         9146
# 42587         6914
# 42588         6711
# 42589          275
# ...            ...
# 42729        33728
# 42730        41365
# 42731         6527
# 42732         3316
# 42733          491
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 42436  2020-12-22T17:00:00              13               Abruzzo
# 42437  2020-12-22T17:00:00              13               Abruzzo
# 42438  2020-12-22T17:00:00              13               Abruzzo
# 42439  2020-12-22T17:00:00              13               Abruzzo
# 42440  2020-12-22T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 42580  2020-12-22T17:00:00               5                Veneto
# 42581  2020-12-22T17:00:00               5                Veneto
# 42582  2020-12-22T17:00:00               5                Veneto
# 42583  2020-12-22T17:00:00               5                Veneto
# 42584  2020-12-22T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#