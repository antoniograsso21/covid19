# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 46156  2021-01-15T17:00:00               5                Veneto
# 46157  2021-01-15T17:00:00               5                Veneto
# 46158  2021-01-15T17:00:00               5                Veneto
# 46159  2021-01-15T17:00:00               5                Veneto
# 46160  2021-01-15T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 46156                27                               Venezia              VE
# 46157                28                                Padova              PD
# 46158                29                                Rovigo              RO
# 46159               899    Fuori Regione / Provincia Autonoma             NaN
# 46160               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 46156        46583
# 46157        53929
# 46158         9063
# 46159         3904
# 46160          584
#
# [46161 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-01-15', '2021-01-14')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 46012  2021-01-15T17:00:00              13               Abruzzo
# 46013  2021-01-15T17:00:00              13               Abruzzo
# 46014  2021-01-15T17:00:00              13               Abruzzo
# 46015  2021-01-15T17:00:00              13               Abruzzo
# 46016  2021-01-15T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 46156  2021-01-15T17:00:00               5                Veneto
# 46157  2021-01-15T17:00:00               5                Veneto
# 46158  2021-01-15T17:00:00               5                Veneto
# 46159  2021-01-15T17:00:00               5                Veneto
# 46160  2021-01-15T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 46012                66                              L'Aquila              AQ
# 46013                67                                Teramo              TE
# 46014                68                               Pescara              PE
# 46015                69                                Chieti              CH
# 46016               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 46156                27                               Venezia              VE
# 46157                28                                Padova              PD
# 46158                29                                Rovigo              RO
# 46159               899    Fuori Regione / Provincia Autonoma             NaN
# 46160               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 46012        11684
# 46013        10258
# 46014         7934
# 46015         8465
# 46016          328
# ...            ...
# 46156        46583
# 46157        53929
# 46158         9063
# 46159         3904
# 46160          584
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 45863  2021-01-14T17:00:00              13               Abruzzo
# 45864  2021-01-14T17:00:00              13               Abruzzo
# 45865  2021-01-14T17:00:00              13               Abruzzo
# 45866  2021-01-14T17:00:00              13               Abruzzo
# 45867  2021-01-14T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 46007  2021-01-14T17:00:00               5                Veneto
# 46008  2021-01-14T17:00:00               5                Veneto
# 46009  2021-01-14T17:00:00               5                Veneto
# 46010  2021-01-14T17:00:00               5                Veneto
# 46011  2021-01-14T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 45863                66                              L'Aquila              AQ
# 45864                67                                Teramo              TE
# 45865                68                               Pescara              PE
# 45866                69                                Chieti              CH
# 45867               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 46007                27                               Venezia              VE
# 46008                28                                Padova              PD
# 46009                29                                Rovigo              RO
# 46010               899    Fuori Regione / Provincia Autonoma             NaN
# 46011               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 45863        11634
# 45864        10215
# 45865         7808
# 45866         8431
# 45867          324
# ...            ...
# 46007        46465
# 46008        53653
# 46009         8996
# 46010         3922
# 46011          593
#
# [149 rows x 7 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-15T17:00:00               1              Piemonte
# 1    2021-01-15T17:00:00               1              Piemonte
# 2    2021-01-15T17:00:00               1              Piemonte
# 3    2021-01-15T17:00:00               1              Piemonte
# 4    2021-01-15T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-15T17:00:00               9               Toscana
# 145  2021-01-15T17:00:00               4           P.A. Trento
# 146  2021-01-15T17:00:00              10                Umbria
# 147  2021-01-15T17:00:00               2         Valle d'Aosta
# 148  2021-01-15T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         110467
# 1           8011
# 2          16584
# 3          29255
# 4          10873
# ..           ...
# 144            0
# 145            0
# 146            0
# 147            9
# 148          584
#
# [149 rows x 7 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-14T17:00:00               1              Piemonte
# 1    2021-01-14T17:00:00               1              Piemonte
# 2    2021-01-14T17:00:00               1              Piemonte
# 3    2021-01-14T17:00:00               1              Piemonte
# 4    2021-01-14T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-14T17:00:00               9               Toscana
# 145  2021-01-14T17:00:00               4           P.A. Trento
# 146  2021-01-14T17:00:00              10                Umbria
# 147  2021-01-14T17:00:00               2         Valle d'Aosta
# 148  2021-01-14T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         110006
# 1           7982
# 2          16522
# 3          29137
# 4          10818
# ..           ...
# 144            0
# 145            0
# 146            0
# 147            9
# 148          593
#
# [149 rows x 7 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-15T17:00:00               1              Piemonte
# 1    2021-01-15T17:00:00               1              Piemonte
# 2    2021-01-15T17:00:00               1              Piemonte
# 3    2021-01-15T17:00:00               1              Piemonte
# 4    2021-01-15T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-15T17:00:00               9               Toscana
# 145  2021-01-15T17:00:00               4           P.A. Trento
# 146  2021-01-15T17:00:00              10                Umbria
# 147  2021-01-15T17:00:00               2         Valle d'Aosta
# 148  2021-01-15T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi  variazione_totale_casi
# 0         110467                     461
# 1           8011                      29
# 2          16584                      62
# 3          29255                     118
# 4          10873                      55
# ..           ...                     ...
# 144            0                       0
# 145            0                       0
# 146            0                       0
# 147            9                       0
# 148          584                      -9
#
# [149 rows x 8 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
