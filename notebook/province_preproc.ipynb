# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 44666  2021-01-05T17:00:00               5                Veneto
# 44667  2021-01-05T17:00:00               5                Veneto
# 44668  2021-01-05T17:00:00               5                Veneto
# 44669  2021-01-05T17:00:00               5                Veneto
# 44670  2021-01-05T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 44666                27                               Venezia              VE
# 44667                28                                Padova              PD
# 44668                29                                Rovigo              RO
# 44669               899    Fuori Regione / Provincia Autonoma             NaN
# 44670               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 44666        42074
# 44667        49293
# 44668         8059
# 44669         3656
# 44670          566
#
# [44671 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-01-05', '2021-01-04')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 44522  2021-01-05T17:00:00              13               Abruzzo
# 44523  2021-01-05T17:00:00              13               Abruzzo
# 44524  2021-01-05T17:00:00              13               Abruzzo
# 44525  2021-01-05T17:00:00              13               Abruzzo
# 44526  2021-01-05T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 44666  2021-01-05T17:00:00               5                Veneto
# 44667  2021-01-05T17:00:00               5                Veneto
# 44668  2021-01-05T17:00:00               5                Veneto
# 44669  2021-01-05T17:00:00               5                Veneto
# 44670  2021-01-05T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 44522                66                              L'Aquila              AQ
# 44523                67                                Teramo              TE
# 44524                68                               Pescara              PE
# 44525                69                                Chieti              CH
# 44526               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 44666                27                               Venezia              VE
# 44667                28                                Padova              PD
# 44668                29                                Rovigo              RO
# 44669               899    Fuori Regione / Provincia Autonoma             NaN
# 44670               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 44522        11211
# 44523         9742
# 44524         7310
# 44525         7562
# 44526          295
# ...            ...
# 44666        42074
# 44667        49293
# 44668         8059
# 44669         3656
# 44670          566
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 44373  2021-01-04T17:00:00              13               Abruzzo
# 44374  2021-01-04T17:00:00              13               Abruzzo
# 44375  2021-01-04T17:00:00              13               Abruzzo
# 44376  2021-01-04T17:00:00              13               Abruzzo
# 44377  2021-01-04T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 44517  2021-01-04T17:00:00               5                Veneto
# 44518  2021-01-04T17:00:00               5                Veneto
# 44519  2021-01-04T17:00:00               5                Veneto
# 44520  2021-01-04T17:00:00               5                Veneto
# 44521  2021-01-04T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 44373                66                              L'Aquila              AQ
# 44374                67                                Teramo              TE
# 44375                68                               Pescara              PE
# 44376                69                                Chieti              CH
# 44377               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 44517                27                               Venezia              VE
# 44518                28                                Padova              PD
# 44519                29                                Rovigo              RO
# 44520               899    Fuori Regione / Provincia Autonoma             NaN
# 44521               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 44373        11183
# 44374         9680
# 44375         7276
# 44376         7476
# 44377          296
# ...            ...
# 44517        41422
# 44518        48355
# 44519         7941
# 44520         3636
# 44521          575
#
# [149 rows x 7 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-05T17:00:00               1              Piemonte
# 1    2021-01-05T17:00:00               1              Piemonte
# 2    2021-01-05T17:00:00               1              Piemonte
# 3    2021-01-05T17:00:00               1              Piemonte
# 4    2021-01-05T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-05T17:00:00               9               Toscana
# 145  2021-01-05T17:00:00               4           P.A. Trento
# 146  2021-01-05T17:00:00              10                Umbria
# 147  2021-01-05T17:00:00               2         Valle d'Aosta
# 148  2021-01-05T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         105872
# 1           7668
# 2          15860
# 3          27803
# 4          10159
# ..           ...
# 144            0
# 145            0
# 146            0
# 147            8
# 148          566
#
# [149 rows x 7 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-04T17:00:00               1              Piemonte
# 1    2021-01-04T17:00:00               1              Piemonte
# 2    2021-01-04T17:00:00               1              Piemonte
# 3    2021-01-04T17:00:00               1              Piemonte
# 4    2021-01-04T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-04T17:00:00               9               Toscana
# 145  2021-01-04T17:00:00               4           P.A. Trento
# 146  2021-01-04T17:00:00              10                Umbria
# 147  2021-01-04T17:00:00               2         Valle d'Aosta
# 148  2021-01-04T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         105342
# 1           7617
# 2          15740
# 3          27605
# 4          10084
# ..           ...
# 144            0
# 145            0
# 146            0
# 147           30
# 148          575
#
# [149 rows x 7 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-05T17:00:00               1              Piemonte
# 1    2021-01-05T17:00:00               1              Piemonte
# 2    2021-01-05T17:00:00               1              Piemonte
# 3    2021-01-05T17:00:00               1              Piemonte
# 4    2021-01-05T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-05T17:00:00               9               Toscana
# 145  2021-01-05T17:00:00               4           P.A. Trento
# 146  2021-01-05T17:00:00              10                Umbria
# 147  2021-01-05T17:00:00               2         Valle d'Aosta
# 148  2021-01-05T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi  variazione_totale_casi
# 0         105872                     530
# 1           7668                      51
# 2          15860                     120
# 3          27803                     198
# 4          10159                      75
# ..           ...                     ...
# 144            0                       0
# 145            0                       0
# 146            0                       0
# 147            8                     -22
# 148          566                      -9
#
# [149 rows x 8 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
