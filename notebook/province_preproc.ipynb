# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 40792  2020-12-10T17:00:00               5                Veneto
# 40793  2020-12-10T17:00:00               5                Veneto
# 40794  2020-12-10T17:00:00               5                Veneto
# 40795  2020-12-10T17:00:00               5                Veneto
# 40796  2020-12-10T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 40792                27                               Venezia              VE
# 40793                28                                Padova              PD
# 40794                29                                Rovigo              RO
# 40795               899    Fuori Regione / Provincia Autonoma             NaN
# 40796               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 40792        26136
# 40793        33125
# 40794         4959
# 40795         3000
# 40796          418
#
# [40797 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2020-12-10', '2020-12-09')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 40648  2020-12-10T17:00:00              13               Abruzzo
# 40649  2020-12-10T17:00:00              13               Abruzzo
# 40650  2020-12-10T17:00:00              13               Abruzzo
# 40651  2020-12-10T17:00:00              13               Abruzzo
# 40652  2020-12-10T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 40792  2020-12-10T17:00:00               5                Veneto
# 40793  2020-12-10T17:00:00               5                Veneto
# 40794  2020-12-10T17:00:00               5                Veneto
# 40795  2020-12-10T17:00:00               5                Veneto
# 40796  2020-12-10T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 40648                66                              L'Aquila              AQ
# 40649                67                                Teramo              TE
# 40650                68                               Pescara              PE
# 40651                69                                Chieti              CH
# 40652               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 40792                27                               Venezia              VE
# 40793                28                                Padova              PD
# 40794                29                                Rovigo              RO
# 40795               899    Fuori Regione / Provincia Autonoma             NaN
# 40796               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 40648        10108
# 40649         8361
# 40650         6309
# 40651         6005
# 40652          259
# ...            ...
# 40792        26136
# 40793        33125
# 40794         4959
# 40795         3000
# 40796          418
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 40499  2020-12-09T17:00:00              13               Abruzzo
# 40500  2020-12-09T17:00:00              13               Abruzzo
# 40501  2020-12-09T17:00:00              13               Abruzzo
# 40502  2020-12-09T17:00:00              13               Abruzzo
# 40503  2020-12-09T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 40643  2020-12-09T17:00:00               5                Veneto
# 40644  2020-12-09T17:00:00               5                Veneto
# 40645  2020-12-09T17:00:00               5                Veneto
# 40646  2020-12-09T17:00:00               5                Veneto
# 40647  2020-12-09T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#