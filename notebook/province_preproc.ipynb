# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 40345  2020-12-07T17:00:00               5                Veneto
# 40346  2020-12-07T17:00:00               5                Veneto
# 40347  2020-12-07T17:00:00               5                Veneto
# 40348  2020-12-07T17:00:00               5                Veneto
# 40349  2020-12-07T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 40345                27                               Venezia              VE
# 40346                28                                Padova              PD
# 40347                29                                Rovigo              RO
# 40348               899    Fuori Regione / Provincia Autonoma             NaN
# 40349               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 40345        24632
# 40346        31486
# 40347         4643
# 40348         2826
# 40349          429
#
# [40350 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2020-12-07', '2020-12-06')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 40201  2020-12-07T17:00:00              13               Abruzzo
# 40202  2020-12-07T17:00:00              13               Abruzzo
# 40203  2020-12-07T17:00:00              13               Abruzzo
# 40204  2020-12-07T17:00:00              13               Abruzzo
# 40205  2020-12-07T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 40345  2020-12-07T17:00:00               5                Veneto
# 40346  2020-12-07T17:00:00               5                Veneto
# 40347  2020-12-07T17:00:00               5                Veneto
# 40348  2020-12-07T17:00:00               5                Veneto
# 40349  2020-12-07T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 40201                66                              L'Aquila              AQ
# 40202                67                                Teramo              TE
# 40203                68                               Pescara              PE
# 40204                69                                Chieti              CH
# 40205               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 40345                27                               Venezia              VE
# 40346                28                                Padova              PD
# 40347                29                                Rovigo              RO
# 40348               899    Fuori Regione / Provincia Autonoma             NaN
# 40349               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 40201         9882
# 40202         8184
# 40203         6111
# 40204         5807
# 40205          249
# ...            ...
# 40345        24632
# 40346        31486
# 40347         4643
# 40348         2826
# 40349          429
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 40052  2020-12-06T17:00:00              13               Abruzzo
# 40053  2020-12-06T17:00:00              13               Abruzzo
# 40054  2020-12-06T17:00:00              13               Abruzzo
# 40055  2020-12-06T17:00:00              13               Abruzzo
# 40056  2020-12-06T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 40196  2020-12-06T17:00:00               5                Veneto
# 40197  2020-12-06T17:00:00               5                Veneto
# 40198  2020-12-06T17:00:00               5                Veneto
# 40199  2020-12-06T17:00:00               5                Veneto
# 40200  2020-12-06T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#