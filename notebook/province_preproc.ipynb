# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note', 'codice_nuts_1', 'codice_nuts_2',
#        'codice_nuts_3'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 51520  2021-02-20T17:00:00               5                Veneto
# 51521  2021-02-20T17:00:00               5                Veneto
# 51522  2021-02-20T17:00:00               5                Veneto
# 51523  2021-02-20T17:00:00               5                Veneto
# 51524  2021-02-20T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 51520                27                               Venezia              VE
# 51521                28                                Padova              PD
# 51522                29                                Rovigo              RO
# 51523               899    Fuori Regione / Provincia Autonoma             NaN
# 51524               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 51520        52383           ITH          ITH3         ITH35
# 51521        60471           ITH          ITH3         ITH36
# 51522        10244           ITH          ITH3         ITH37
# 51523         4363           ITH          ITH3           NaN
# 51524          555           ITH          ITH3           NaN
#
# [51525 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-02-20', '2021-02-19')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 51376  2021-02-20T17:00:00              13               Abruzzo
# 51377  2021-02-20T17:00:00              13               Abruzzo
# 51378  2021-02-20T17:00:00              13               Abruzzo
# 51379  2021-02-20T17:00:00              13               Abruzzo
# 51380  2021-02-20T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 51520  2021-02-20T17:00:00               5                Veneto
# 51521  2021-02-20T17:00:00               5                Veneto
# 51522  2021-02-20T17:00:00               5                Veneto
# 51523  2021-02-20T17:00:00               5                Veneto
# 51524  2021-02-20T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 51376                66                              L'Aquila              AQ
# 51377                67                                Teramo              TE
# 51378                68                               Pescara              PE
# 51379                69                                Chieti              CH
# 51380               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 51520                27                               Venezia              VE
# 51521                28                                Padova              PD
# 51522                29                                Rovigo              RO
# 51523               899    Fuori Regione / Provincia Autonoma             NaN
# 51524               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 51376        12919           ITF          ITF1         ITF11
# 51377        12161           ITF          ITF1         ITF12
# 51378        12629           ITF          ITF1         ITF13
# 51379        12291           ITF          ITF1         ITF14
# 51380          415           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 51520        52383           ITH          ITH3         ITH35
# 51521        60471           ITH          ITH3         ITH36
# 51522        10244           ITH          ITH3         ITH37
# 51523         4363           ITH          ITH3           NaN
# 51524          555           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 51227  2021-02-19T17:00:00              13               Abruzzo
# 51228  2021-02-19T17:00:00              13               Abruzzo
# 51229  2021-02-19T17:00:00              13               Abruzzo
# 51230  2021-02-19T17:00:00              13               Abruzzo
# 51231  2021-02-19T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
#