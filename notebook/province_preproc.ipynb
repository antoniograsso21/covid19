# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 45262  2021-01-09T17:00:00               5                Veneto
# 45263  2021-01-09T17:00:00               5                Veneto
# 45264  2021-01-09T17:00:00               5                Veneto
# 45265  2021-01-09T17:00:00               5                Veneto
# 45266  2021-01-09T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 45262                27                               Venezia              VE
# 45263                28                                Padova              PD
# 45264                29                                Rovigo              RO
# 45265               899    Fuori Regione / Provincia Autonoma             NaN
# 45266               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 45262        44405
# 45263        51664
# 45264         8605
# 45265         3811
# 45266          577
#
# [45267 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-01-09', '2021-01-08')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 45118  2021-01-09T17:00:00              13               Abruzzo
# 45119  2021-01-09T17:00:00              13               Abruzzo
# 45120  2021-01-09T17:00:00              13               Abruzzo
# 45121  2021-01-09T17:00:00              13               Abruzzo
# 45122  2021-01-09T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 45262  2021-01-09T17:00:00               5                Veneto
# 45263  2021-01-09T17:00:00               5                Veneto
# 45264  2021-01-09T17:00:00               5                Veneto
# 45265  2021-01-09T17:00:00               5                Veneto
# 45266  2021-01-09T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 45118                66                              L'Aquila              AQ
# 45119                67                                Teramo              TE
# 45120                68                               Pescara              PE
# 45121                69                                Chieti              CH
# 45122               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 45262                27                               Venezia              VE
# 45263                28                                Padova              PD
# 45264                29                                Rovigo              RO
# 45265               899    Fuori Regione / Provincia Autonoma             NaN
# 45266               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 45118        11419
# 45119         9994
# 45120         7526
# 45121         8018
# 45122          311
# ...            ...
# 45262        44405
# 45263        51664
# 45264         8605
# 45265         3811
# 45266          577
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 44969  2021-01-08T17:00:00              13               Abruzzo
# 44970  2021-01-08T17:00:00              13               Abruzzo
# 44971  2021-01-08T17:00:00              13               Abruzzo
# 44972  2021-01-08T17:00:00              13               Abruzzo
# 44973  2021-01-08T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 45113  2021-01-08T17:00:00               5                Veneto
# 45114  2021-01-08T17:00:00               5                Veneto
# 45115  2021-01-08T17:00:00               5                Veneto
# 45116  2021-01-08T17:00:00               5                Veneto
# 45117  2021-01-08T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#