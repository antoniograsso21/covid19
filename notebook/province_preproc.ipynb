# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 43623  2020-12-29T17:00:00               5                Veneto
# 43624  2020-12-29T17:00:00               5                Veneto
# 43625  2020-12-29T17:00:00               5                Veneto
# 43626  2020-12-29T17:00:00               5                Veneto
# 43627  2020-12-29T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 43623                27                               Venezia              VE
# 43624                28                                Padova              PD
# 43625                29                                Rovigo              RO
# 43626               899    Fuori Regione / Provincia Autonoma             NaN
# 43627               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 43623        37585
# 43624        45071
# 43625         7225
# 43626         3470
# 43627          547
#
# [43628 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2020-12-29', '2020-12-28')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 43479  2020-12-29T17:00:00              13               Abruzzo
# 43480  2020-12-29T17:00:00              13               Abruzzo
# 43481  2020-12-29T17:00:00              13               Abruzzo
# 43482  2020-12-29T17:00:00              13               Abruzzo
# 43483  2020-12-29T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 43623  2020-12-29T17:00:00               5                Veneto
# 43624  2020-12-29T17:00:00               5                Veneto
# 43625  2020-12-29T17:00:00               5                Veneto
# 43626  2020-12-29T17:00:00               5                Veneto
# 43627  2020-12-29T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 43479                66                              L'Aquila              AQ
# 43480                67                                Teramo              TE
# 43481                68                               Pescara              PE
# 43482                69                                Chieti              CH
# 43483               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 43623                27                               Venezia              VE
# 43624                28                                Padova              PD
# 43625                29                                Rovigo              RO
# 43626               899    Fuori Regione / Provincia Autonoma             NaN
# 43627               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 43479        10850
# 43480         9283
# 43481         7048
# 43482         6964
# 43483          280
# ...            ...
# 43623        37585
# 43624        45071
# 43625         7225
# 43626         3470
# 43627          547
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 43330  2020-12-28T17:00:00              13               Abruzzo
# 43331  2020-12-28T17:00:00              13               Abruzzo
# 43332  2020-12-28T17:00:00              13               Abruzzo
# 43333  2020-12-28T17:00:00              13               Abruzzo
# 43334  2020-12-28T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 43474  2020-12-28T17:00:00               5                Veneto
# 43475  2020-12-28T17:00:00               5                Veneto
# 43476  2020-12-28T17:00:00               5                Veneto
# 43477  2020-12-28T17:00:00               5                Veneto
# 43478  2020-12-28T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#