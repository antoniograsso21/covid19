# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note', 'codice_nuts_1', 'codice_nuts_2',
#        'codice_nuts_3'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 49583  2021-02-07T17:00:00               5                Veneto
# 49584  2021-02-07T17:00:00               5                Veneto
# 49585  2021-02-07T17:00:00               5                Veneto
# 49586  2021-02-07T17:00:00               5                Veneto
# 49587  2021-02-07T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 49583                27                               Venezia              VE
# 49584                28                                Padova              PD
# 49585                29                                Rovigo              RO
# 49586               899    Fuori Regione / Provincia Autonoma             NaN
# 49587               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 49583        50779           ITH          ITH3         ITH35
# 49584        58408           ITH          ITH3         ITH36
# 49585         9829           ITH          ITH3         ITH37
# 49586         4295           ITH          ITH3           NaN
# 49587          571           ITH          ITH3           NaN
#
# [49588 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-02-07', '2021-02-06')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 49439  2021-02-07T17:00:00              13               Abruzzo
# 49440  2021-02-07T17:00:00              13               Abruzzo
# 49441  2021-02-07T17:00:00              13               Abruzzo
# 49442  2021-02-07T17:00:00              13               Abruzzo
# 49443  2021-02-07T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 49583  2021-02-07T17:00:00               5                Veneto
# 49584  2021-02-07T17:00:00               5                Veneto
# 49585  2021-02-07T17:00:00               5                Veneto
# 49586  2021-02-07T17:00:00               5                Veneto
# 49587  2021-02-07T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 49439                66                              L'Aquila              AQ
# 49440                67                                Teramo              TE
# 49441                68                               Pescara              PE
# 49442                69                                Chieti              CH
# 49443               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 49583                27                               Venezia              VE
# 49584                28                                Padova              PD
# 49585                29                                Rovigo              RO
# 49586               899    Fuori Regione / Provincia Autonoma             NaN
# 49587               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 49439        12422           ITF          ITF1         ITF11
# 49440        11502           ITF          ITF1         ITF12
# 49441        10328           ITF          ITF1         ITF13
# 49442        10597           ITF          ITF1         ITF14
# 49443          378           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 49583        50779           ITH          ITH3         ITH35
# 49584        58408           ITH          ITH3         ITH36
# 49585         9829           ITH          ITH3         ITH37
# 49586         4295           ITH          ITH3           NaN
# 49587          571           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 49290  2021-02-06T17:00:00              13               Abruzzo
# 49291  2021-02-06T17:00:00              13               Abruzzo
# 49292  2021-02-06T17:00:00              13               Abruzzo
# 49293  2021-02-06T17:00:00              13               Abruzzo
# 49294  2021-02-06T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 49434  2021-02-06T17:00:00               5                Veneto
# 49435  2021-02-06T17:00:00               5                Veneto
# 49436  2021-02-06T17:00:00               5                Veneto
# 49437  2021-02-06T17:00:00               5                Veneto
# 49438  2021-02-06T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 49290                66                              L'Aquila              AQ
# 49291                67                                Teramo              TE
# 49292                68                               Pescara              PE
# 49293                69                                Chieti              CH
# 49294               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 49434                27                               Venezia              VE
# 49435                28                                Padova              PD
# 49436                29                                Rovigo              RO
# 49437               899    Fuori Regione / Provincia Autonoma             NaN
# 49438               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 49290        12397           ITF          ITF1         ITF11
# 49291        11415           ITF          ITF1         ITF12
# 49292        10167           ITF          ITF1         ITF13
# 49293        10440           ITF          ITF1         ITF14
# 49294          375           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 49434        50720           ITH          ITH3         ITH35
# 49435        58248           ITH          ITH3         ITH36
# 49436         9815           ITH          ITH3         ITH37
# 49437         4288           ITH          ITH3           NaN
# 49438          569           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-02-07T17:00:00               1              Piemonte
# 1    2021-02-07T17:00:00               1              Piemonte
# 2    2021-02-07T17:00:00               1              Piemonte
# 3    2021-02-07T17:00:00               1              Piemonte
# 4    2021-02-07T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-02-07T17:00:00               9               Toscana
# 145  2021-02-07T17:00:00               4           P.A. Trento
# 146  2021-02-07T17:00:00              10                Umbria
# 147  2021-02-07T17:00:00               2         Valle d'Aosta
# 148  2021-02-07T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         119859           ITC          ITC1         ITC11
# 1           8453           ITC          ITC1         ITC12
# 2          17941           ITC          ITC1         ITC15
# 3          31194           ITC          ITC1         ITC16
# 4          11808           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          571           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-02-06T17:00:00               1              Piemonte
# 1    2021-02-06T17:00:00               1              Piemonte
# 2    2021-02-06T17:00:00               1              Piemonte
# 3    2021-02-06T17:00:00               1              Piemonte
# 4    2021-02-06T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-02-06T17:00:00               9               Toscana
# 145  2021-02-06T17:00:00               4           P.A. Trento
# 146  2021-02-06T17:00:00              10                Umbria
# 147  2021-02-06T17:00:00               2         Valle d'Aosta
# 148  2021-02-06T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         119438           ITC          ITC1         ITC11
# 1           8447           ITC          ITC1         ITC12
# 2          17897           ITC          ITC1         ITC15
# 3          31148           ITC          ITC1         ITC16
# 4          11763           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          569           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-02-07T17:00:00               1              Piemonte
# 1    2021-02-07T17:00:00               1              Piemonte
# 2    2021-02-07T17:00:00               1              Piemonte
# 3    2021-02-07T17:00:00               1              Piemonte
# 4    2021-02-07T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-02-07T17:00:00               9               Toscana
# 145  2021-02-07T17:00:00               4           P.A. Trento
# 146  2021-02-07T17:00:00              10                Umbria
# 147  2021-02-07T17:00:00               2         Valle d'Aosta
# 148  2021-02-07T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         119859           ITC          ITC1         ITC11
# 1           8453           ITC          ITC1         ITC12
# 2          17941           ITC          ITC1         ITC15
# 3          31194           ITC          ITC1         ITC16
# 4          11808           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          571           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                       421
# 1                         6
# 2                        44
# 3                        46
# 4                        45
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                       0
# 148                       2
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
