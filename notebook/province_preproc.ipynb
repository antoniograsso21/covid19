# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 43176  2020-12-26T17:00:00               5                Veneto
# 43177  2020-12-26T17:00:00               5                Veneto
# 43178  2020-12-26T17:00:00               5                Veneto
# 43179  2020-12-26T17:00:00               5                Veneto
# 43180  2020-12-26T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 43176                27                               Venezia              VE
# 43177                28                                Padova              PD
# 43178                29                                Rovigo              RO
# 43179               899    Fuori Regione / Provincia Autonoma             NaN
# 43180               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 43176        35943
# 43177        43245
# 43178         6957
# 43179         3421
# 43180          538
#
# [43181 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2020-12-26', '2020-12-25')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 43032  2020-12-26T17:00:00              13               Abruzzo
# 43033  2020-12-26T17:00:00              13               Abruzzo
# 43034  2020-12-26T17:00:00              13               Abruzzo
# 43035  2020-12-26T17:00:00              13               Abruzzo
# 43036  2020-12-26T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 43176  2020-12-26T17:00:00               5                Veneto
# 43177  2020-12-26T17:00:00               5                Veneto
# 43178  2020-12-26T17:00:00               5                Veneto
# 43179  2020-12-26T17:00:00               5                Veneto
# 43180  2020-12-26T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 43032                66                              L'Aquila              AQ
# 43033                67                                Teramo              TE
# 43034                68                               Pescara              PE
# 43035                69                                Chieti              CH
# 43036               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 43176                27                               Venezia              VE
# 43177                28                                Padova              PD
# 43178                29                                Rovigo              RO
# 43179               899    Fuori Regione / Provincia Autonoma             NaN
# 43180               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 43032        10815
# 43033         9264
# 43034         7016
# 43035         6936
# 43036          281
# ...            ...
# 43176        35943
# 43177        43245
# 43178         6957
# 43179         3421
# 43180          538
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 42883  2020-12-25T17:00:00              13               Abruzzo
# 42884  2020-12-25T17:00:00              13               Abruzzo
# 42885  2020-12-25T17:00:00              13               Abruzzo
# 42886  2020-12-25T17:00:00              13               Abruzzo
# 42887  2020-12-25T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 43027  2020-12-25T17:00:00               5                Veneto
# 43028  2020-12-25T17:00:00               5                Veneto
# 43029  2020-12-25T17:00:00               5                Veneto
# 43030  2020-12-25T17:00:00               5                Veneto
# 43031  2020-12-25T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
#