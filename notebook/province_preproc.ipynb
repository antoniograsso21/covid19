# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note', 'codice_nuts_1', 'codice_nuts_2',
#        'codice_nuts_3'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 48540  2021-01-31T17:00:00               5                Veneto
# 48541  2021-01-31T17:00:00               5                Veneto
# 48542  2021-01-31T17:00:00               5                Veneto
# 48543  2021-01-31T17:00:00               5                Veneto
# 48544  2021-01-31T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 48540                27                               Venezia              VE
# 48541                28                                Padova              PD
# 48542                29                                Rovigo              RO
# 48543               899    Fuori Regione / Provincia Autonoma             NaN
# 48544               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 48540        50112           ITH          ITH3         ITH35
# 48541        57326           ITH          ITH3         ITH36
# 48542         9610           ITH          ITH3         ITH37
# 48543         4199           ITH          ITH3           NaN
# 48544          597           ITH          ITH3           NaN
#
# [48545 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-01-31', '2021-01-30')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 48396  2021-01-31T17:00:00              13               Abruzzo
# 48397  2021-01-31T17:00:00              13               Abruzzo
# 48398  2021-01-31T17:00:00              13               Abruzzo
# 48399  2021-01-31T17:00:00              13               Abruzzo
# 48400  2021-01-31T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 48540  2021-01-31T17:00:00               5                Veneto
# 48541  2021-01-31T17:00:00               5                Veneto
# 48542  2021-01-31T17:00:00               5                Veneto
# 48543  2021-01-31T17:00:00               5                Veneto
# 48544  2021-01-31T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 48396                66                              L'Aquila              AQ
# 48397                67                                Teramo              TE
# 48398                68                               Pescara              PE
# 48399                69                                Chieti              CH
# 48400               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 48540                27                               Venezia              VE
# 48541                28                                Padova              PD
# 48542                29                                Rovigo              RO
# 48543               899    Fuori Regione / Provincia Autonoma             NaN
# 48544               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 48396        12164           ITF          ITF1         ITF11
# 48397        11101           ITF          ITF1         ITF12
# 48398         9290           ITF          ITF1         ITF13
# 48399         9748           ITF          ITF1         ITF14
# 48400          364           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 48540        50112           ITH          ITH3         ITH35
# 48541        57326           ITH          ITH3         ITH36
# 48542         9610           ITH          ITH3         ITH37
# 48543         4199           ITH          ITH3           NaN
# 48544          597           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 48247  2021-01-30T17:00:00              13               Abruzzo
# 48248  2021-01-30T17:00:00              13               Abruzzo
# 48249  2021-01-30T17:00:00              13               Abruzzo
# 48250  2021-01-30T17:00:00              13               Abruzzo
# 48251  2021-01-30T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
#