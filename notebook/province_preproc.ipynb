# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note', 'codice_nuts_1', 'codice_nuts_2',
#        'codice_nuts_3'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 49136  2021-02-04T17:00:00               5                Veneto
# 49137  2021-02-04T17:00:00               5                Veneto
# 49138  2021-02-04T17:00:00               5                Veneto
# 49139  2021-02-04T17:00:00               5                Veneto
# 49140  2021-02-04T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 49136                27                               Venezia              VE
# 49137                28                                Padova              PD
# 49138                29                                Rovigo              RO
# 49139               899    Fuori Regione / Provincia Autonoma             NaN
# 49140               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 49136        50493           ITH          ITH3         ITH35
# 49137        57883           ITH          ITH3         ITH36
# 49138         9746           ITH          ITH3         ITH37
# 49139         4263           ITH          ITH3           NaN
# 49140          568           ITH          ITH3           NaN
#
# [49141 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-02-04', '2021-02-03')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 48992  2021-02-04T17:00:00              13               Abruzzo
# 48993  2021-02-04T17:00:00              13               Abruzzo
# 48994  2021-02-04T17:00:00              13               Abruzzo
# 48995  2021-02-04T17:00:00              13               Abruzzo
# 48996  2021-02-04T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 49136  2021-02-04T17:00:00               5                Veneto
# 49137  2021-02-04T17:00:00               5                Veneto
# 49138  2021-02-04T17:00:00               5                Veneto
# 49139  2021-02-04T17:00:00               5                Veneto
# 49140  2021-02-04T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 48992                66                              L'Aquila              AQ
# 48993                67                                Teramo              TE
# 48994                68                               Pescara              PE
# 48995                69                                Chieti              CH
# 48996               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 49136                27                               Venezia              VE
# 49137                28                                Padova              PD
# 49138                29                                Rovigo              RO
# 49139               899    Fuori Regione / Provincia Autonoma             NaN
# 49140               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 48992        12310           ITF          ITF1         ITF11
# 48993        11310           ITF          ITF1         ITF12
# 48994         9827           ITF          ITF1         ITF13
# 48995        10196           ITF          ITF1         ITF14
# 48996          371           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 49136        50493           ITH          ITH3         ITH35
# 49137        57883           ITH          ITH3         ITH36
# 49138         9746           ITH          ITH3         ITH37
# 49139         4263           ITH          ITH3           NaN
# 49140          568           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 48843  2021-02-03T17:00:00              13               Abruzzo
# 48844  2021-02-03T17:00:00              13               Abruzzo
# 48845  2021-02-03T17:00:00              13               Abruzzo
# 48846  2021-02-03T17:00:00              13               Abruzzo
# 48847  2021-02-03T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
#