# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note', 'codice_nuts_1', 'codice_nuts_2',
#        'codice_nuts_3'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 46603  2021-01-18T17:00:00               5                Veneto
# 46604  2021-01-18T17:00:00               5                Veneto
# 46605  2021-01-18T17:00:00               5                Veneto
# 46606  2021-01-18T17:00:00               5                Veneto
# 46607  2021-01-18T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 46603                27                               Venezia              VE
# 46604                28                                Padova              PD
# 46605                29                                Rovigo              RO
# 46606               899    Fuori Regione / Provincia Autonoma             NaN
# 46607               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 46603        47453           ITH          ITH3         ITH35
# 46604        54804           ITH          ITH3         ITH36
# 46605         9185           ITH          ITH3         ITH37
# 46606         3979           ITH          ITH3           NaN
# 46607          594           ITH          ITH3           NaN
#
# [46608 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-01-18', '2021-01-17')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 46459  2021-01-18T17:00:00              13               Abruzzo
# 46460  2021-01-18T17:00:00              13               Abruzzo
# 46461  2021-01-18T17:00:00              13               Abruzzo
# 46462  2021-01-18T17:00:00              13               Abruzzo
# 46463  2021-01-18T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 46603  2021-01-18T17:00:00               5                Veneto
# 46604  2021-01-18T17:00:00               5                Veneto
# 46605  2021-01-18T17:00:00               5                Veneto
# 46606  2021-01-18T17:00:00               5                Veneto
# 46607  2021-01-18T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 46459                66                              L'Aquila              AQ
# 46460                67                                Teramo              TE
# 46461                68                               Pescara              PE
# 46462                69                                Chieti              CH
# 46463               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 46603                27                               Venezia              VE
# 46604                28                                Padova              PD
# 46605                29                                Rovigo              RO
# 46606               899    Fuori Regione / Provincia Autonoma             NaN
# 46607               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 46459        11757           ITF          ITF1         ITF11
# 46460        10389           ITF          ITF1         ITF12
# 46461         8090           ITF          ITF1         ITF13
# 46462         8673           ITF          ITF1         ITF14
# 46463          339           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 46603        47453           ITH          ITH3         ITH35
# 46604        54804           ITH          ITH3         ITH36
# 46605         9185           ITH          ITH3         ITH37
# 46606         3979           ITH          ITH3           NaN
# 46607          594           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 46310  2021-01-17T17:00:00              13               Abruzzo
# 46311  2021-01-17T17:00:00              13               Abruzzo
# 46312  2021-01-17T17:00:00              13               Abruzzo
# 46313  2021-01-17T17:00:00              13               Abruzzo
# 46314  2021-01-17T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
#