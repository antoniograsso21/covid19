# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note', 'codice_nuts_1', 'codice_nuts_2',
#        'codice_nuts_3'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 51222  2021-02-18T17:00:00               5                Veneto
# 51223  2021-02-18T17:00:00               5                Veneto
# 51224  2021-02-18T17:00:00               5                Veneto
# 51225  2021-02-18T17:00:00               5                Veneto
# 51226  2021-02-18T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 51222                27                               Venezia              VE
# 51223                28                                Padova              PD
# 51224                29                                Rovigo              RO
# 51225               899    Fuori Regione / Provincia Autonoma             NaN
# 51226               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 51222        52073           ITH          ITH3         ITH35
# 51223        59973           ITH          ITH3         ITH36
# 51224        10157           ITH          ITH3         ITH37
# 51225         4349           ITH          ITH3           NaN
# 51226          563           ITH          ITH3           NaN
#
# [51227 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-02-18', '2021-02-17')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 51078  2021-02-18T17:00:00              13               Abruzzo
# 51079  2021-02-18T17:00:00              13               Abruzzo
# 51080  2021-02-18T17:00:00              13               Abruzzo
# 51081  2021-02-18T17:00:00              13               Abruzzo
# 51082  2021-02-18T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 51222  2021-02-18T17:00:00               5                Veneto
# 51223  2021-02-18T17:00:00               5                Veneto
# 51224  2021-02-18T17:00:00               5                Veneto
# 51225  2021-02-18T17:00:00               5                Veneto
# 51226  2021-02-18T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 51078                66                              L'Aquila              AQ
# 51079                67                                Teramo              TE
# 51080                68                               Pescara              PE
# 51081                69                                Chieti              CH
# 51082               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 51222                27                               Venezia              VE
# 51223                28                                Padova              PD
# 51224                29                                Rovigo              RO
# 51225               899    Fuori Regione / Provincia Autonoma             NaN
# 51226               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 51078        12834           ITF          ITF1         ITF11
# 51079        12021           ITF          ITF1         ITF12
# 51080        12253           ITF          ITF1         ITF13
# 51081        12022           ITF          ITF1         ITF14
# 51082          411           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 51222        52073           ITH          ITH3         ITH35
# 51223        59973           ITH          ITH3         ITH36
# 51224        10157           ITH          ITH3         ITH37
# 51225         4349           ITH          ITH3           NaN
# 51226          563           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 50929  2021-02-17T17:00:00              13               Abruzzo
# 50930  2021-02-17T17:00:00              13               Abruzzo
# 50931  2021-02-17T17:00:00              13               Abruzzo
# 50932  2021-02-17T17:00:00              13               Abruzzo
# 50933  2021-02-17T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 51073  2021-02-17T17:00:00               5                Veneto
# 51074  2021-02-17T17:00:00               5                Veneto
# 51075  2021-02-17T17:00:00               5                Veneto
# 51076  2021-02-17T17:00:00               5                Veneto
# 51077  2021-02-17T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 50929                66                              L'Aquila              AQ
# 50930                67                                Teramo              TE
# 50931                68                               Pescara              PE
# 50932                69                                Chieti              CH
# 50933               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 51073                27                               Venezia              VE
# 51074                28                                Padova              PD
# 51075                29                                Rovigo              RO
# 51076               899    Fuori Regione / Provincia Autonoma             NaN
# 51077               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 50929        12787           ITF          ITF1         ITF11
# 50930        11944           ITF          ITF1         ITF12
# 50931        12061           ITF          ITF1         ITF13
# 50932        11830           ITF          ITF1         ITF14
# 50933          405           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 51073        51904           ITH          ITH3         ITH35
# 51074        59706           ITH          ITH3         ITH36
# 51075        10103           ITH          ITH3         ITH37
# 51076         4379           ITH          ITH3           NaN
# 51077          561           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-02-18T17:00:00               1              Piemonte
# 1    2021-02-18T17:00:00               1              Piemonte
# 2    2021-02-18T17:00:00               1              Piemonte
# 3    2021-02-18T17:00:00               1              Piemonte
# 4    2021-02-18T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-02-18T17:00:00               9               Toscana
# 145  2021-02-18T17:00:00               4           P.A. Trento
# 146  2021-02-18T17:00:00              10                Umbria
# 147  2021-02-18T17:00:00               2         Valle d'Aosta
# 148  2021-02-18T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         124515           ITC          ITC1         ITC11
# 1           8693           ITC          ITC1         ITC12
# 2          18448           ITC          ITC1         ITC15
# 3          31977           ITC          ITC1         ITC16
# 4          12153           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          563           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-02-17T17:00:00               1              Piemonte
# 1    2021-02-17T17:00:00               1              Piemonte
# 2    2021-02-17T17:00:00               1              Piemonte
# 3    2021-02-17T17:00:00               1              Piemonte
# 4    2021-02-17T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-02-17T17:00:00               9               Toscana
# 145  2021-02-17T17:00:00               4           P.A. Trento
# 146  2021-02-17T17:00:00              10                Umbria
# 147  2021-02-17T17:00:00               2         Valle d'Aosta
# 148  2021-02-17T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         124245           ITC          ITC1         ITC11
# 1           8661           ITC          ITC1         ITC12
# 2          18439           ITC          ITC1         ITC15
# 3          31888           ITC          ITC1         ITC16
# 4          12137           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          561           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-02-18T17:00:00               1              Piemonte
# 1    2021-02-18T17:00:00               1              Piemonte
# 2    2021-02-18T17:00:00               1              Piemonte
# 3    2021-02-18T17:00:00               1              Piemonte
# 4    2021-02-18T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-02-18T17:00:00               9               Toscana
# 145  2021-02-18T17:00:00               4           P.A. Trento
# 146  2021-02-18T17:00:00              10                Umbria
# 147  2021-02-18T17:00:00               2         Valle d'Aosta
# 148  2021-02-18T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         124515           ITC          ITC1         ITC11
# 1           8693           ITC          ITC1         ITC12
# 2          18448           ITC          ITC1         ITC15
# 3          31977           ITC          ITC1         ITC16
# 4          12153           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          563           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                       270
# 1                        32
# 2                         9
# 3                        89
# 4                        16
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                       0
# 148                       2
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
