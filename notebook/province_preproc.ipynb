# %%
import sys
import time
import requests
import datetime
import pandas as pd

sys.path.append('../')
from src.util.functions import Functions

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = '../data'
path_csv = '{path_data}/csv'.format(path_data=path_data)
csv_out_name = '{path_csv}/covid19-{level}.csv'.format(path_csv=path_csv, level=level)

# %%
url_cum = Functions.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
df_raw_p.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note'],
#       dtype='object')

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 44368  2021-01-03T17:00:00               5                Veneto
# 44369  2021-01-03T17:00:00               5                Veneto
# 44370  2021-01-03T17:00:00               5                Veneto
# 44371  2021-01-03T17:00:00               5                Veneto
# 44372  2021-01-03T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 44368                27                               Venezia              VE
# 44369                28                                Padova              PD
# 44370                29                                Rovigo              RO
# 44371               899    Fuori Regione / Provincia Autonoma             NaN
# 44372               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 44368        40895
# 44369        48110
# 44370         7876
# 44371         3624
# 44372          572
#
# [44373 rows x 7 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = Functions.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-01-03', '2021-01-02')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 44224  2021-01-03T17:00:00              13               Abruzzo
# 44225  2021-01-03T17:00:00              13               Abruzzo
# 44226  2021-01-03T17:00:00              13               Abruzzo
# 44227  2021-01-03T17:00:00              13               Abruzzo
# 44228  2021-01-03T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 44368  2021-01-03T17:00:00               5                Veneto
# 44369  2021-01-03T17:00:00               5                Veneto
# 44370  2021-01-03T17:00:00               5                Veneto
# 44371  2021-01-03T17:00:00               5                Veneto
# 44372  2021-01-03T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 44224                66                              L'Aquila              AQ
# 44225                67                                Teramo              TE
# 44226                68                               Pescara              PE
# 44227                69                                Chieti              CH
# 44228               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 44368                27                               Venezia              VE
# 44369                28                                Padova              PD
# 44370                29                                Rovigo              RO
# 44371               899    Fuori Regione / Provincia Autonoma             NaN
# 44372               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 44224        11165
# 44225         9623
# 44226         7270
# 44227         7439
# 44228          293
# ...            ...
# 44368        40895
# 44369        48110
# 44370         7876
# 44371         3624
# 44372          572
#
# [149 rows x 7 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 44075  2021-01-02T17:00:00              13               Abruzzo
# 44076  2021-01-02T17:00:00              13               Abruzzo
# 44077  2021-01-02T17:00:00              13               Abruzzo
# 44078  2021-01-02T17:00:00              13               Abruzzo
# 44079  2021-01-02T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 44219  2021-01-02T17:00:00               5                Veneto
# 44220  2021-01-02T17:00:00               5                Veneto
# 44221  2021-01-02T17:00:00               5                Veneto
# 44222  2021-01-02T17:00:00               5                Veneto
# 44223  2021-01-02T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 44075                66                              L'Aquila              AQ
# 44076                67                                Teramo              TE
# 44077                68                               Pescara              PE
# 44078                69                                Chieti              CH
# 44079               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 44219                27                               Venezia              VE
# 44220                28                                Padova              PD
# 44221                29                                Rovigo              RO
# 44222               899    Fuori Regione / Provincia Autonoma             NaN
# 44223               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi
# 44075        11119
# 44076         9524
# 44077         7246
# 44078         7403
# 44079          291
# ...            ...
# 44219        40415
# 44220        47321
# 44221         7759
# 44222         3603
# 44223          569
#
# [149 rows x 7 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-03T17:00:00               1              Piemonte
# 1    2021-01-03T17:00:00               1              Piemonte
# 2    2021-01-03T17:00:00               1              Piemonte
# 3    2021-01-03T17:00:00               1              Piemonte
# 4    2021-01-03T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-03T17:00:00               9               Toscana
# 145  2021-01-03T17:00:00               4           P.A. Trento
# 146  2021-01-03T17:00:00              10                Umbria
# 147  2021-01-03T17:00:00               2         Valle d'Aosta
# 148  2021-01-03T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         105154
# 1           7611
# 2          15684
# 3          27541
# 4          10042
# ..           ...
# 144            0
# 145            0
# 146            0
# 147           30
# 148          572
#
# [149 rows x 7 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-02T17:00:00               1              Piemonte
# 1    2021-01-02T17:00:00               1              Piemonte
# 2    2021-01-02T17:00:00               1              Piemonte
# 3    2021-01-02T17:00:00               1              Piemonte
# 4    2021-01-02T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-02T17:00:00               9               Toscana
# 145  2021-01-02T17:00:00               4           P.A. Trento
# 146  2021-01-02T17:00:00              10                Umbria
# 147  2021-01-02T17:00:00               2         Valle d'Aosta
# 148  2021-01-02T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi
# 0         104803
# 1           7591
# 2          15598
# 3          27421
# 4           9986
# ..           ...
# 144            0
# 145            0
# 146            0
# 147           30
# 148          569
#
# [149 rows x 7 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-01-03T17:00:00               1              Piemonte
# 1    2021-01-03T17:00:00               1              Piemonte
# 2    2021-01-03T17:00:00               1              Piemonte
# 3    2021-01-03T17:00:00               1              Piemonte
# 4    2021-01-03T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-01-03T17:00:00               9               Toscana
# 145  2021-01-03T17:00:00               4           P.A. Trento
# 146  2021-01-03T17:00:00              10                Umbria
# 147  2021-01-03T17:00:00               2         Valle d'Aosta
# 148  2021-01-03T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi  variazione_totale_casi
# 0         105154                     351
# 1           7611                      20
# 2          15684                      86
# 3          27541                     120
# 4          10042                      56
# ..           ...                     ...
# 144            0                       0
# 145            0                       0
# 146            0                       0
# 147           30                       0
# 148          572                       3
#
# [149 rows x 8 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
