# %%
import sys
import time
import requests
import datetime
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv'
csv_out_name = f'{path_csv}/covid19-{level}.csv'

# %%
url_cum = F.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
list(df_raw_p.columns)
# Out:
# ['data',
#  'stato',
#  'codice_regione',
#  'denominazione_regione',
#  'codice_provincia',
#  'denominazione_provincia',
#  'sigla_provincia',
#  'lat',
#  'long',
#  'totale_casi',
#  'note',
#  'codice_nuts_1',
#  'codice_nuts_2',
#  'codice_nuts_3']

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 56586  2021-03-26T17:00:00               5                Veneto
# 56587  2021-03-26T17:00:00               5                Veneto
# 56588  2021-03-26T17:00:00               5                Veneto
# 56589  2021-03-26T17:00:00               5                Veneto
# 56590  2021-03-26T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 56586                27                               Venezia              VE
# 56587                28                                Padova              PD
# 56588                29                                Rovigo              RO
# 56589               899    Fuori Regione / Provincia Autonoma             NaN
# 56590               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 56586        61264           ITH          ITH3         ITH35
# 56587        71386           ITH          ITH3         ITH36
# 56588        12427           ITH          ITH3         ITH37
# 56589         4923           ITH          ITH3           NaN
# 56590          667           ITH          ITH3           NaN
#
# [56591 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = F.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-03-26', '2021-03-25')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 56442  2021-03-26T17:00:00              13               Abruzzo
# 56443  2021-03-26T17:00:00              13               Abruzzo
# 56444  2021-03-26T17:00:00              13               Abruzzo
# 56445  2021-03-26T17:00:00              13               Abruzzo
# 56446  2021-03-26T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 56586  2021-03-26T17:00:00               5                Veneto
# 56587  2021-03-26T17:00:00               5                Veneto
# 56588  2021-03-26T17:00:00               5                Veneto
# 56589  2021-03-26T17:00:00               5                Veneto
# 56590  2021-03-26T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 56442                66                              L'Aquila              AQ
# 56443                67                                Teramo              TE
# 56444                68                               Pescara              PE
# 56445                69                                Chieti              CH
# 56446               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 56586                27                               Venezia              VE
# 56587                28                                Padova              PD
# 56588                29                                Rovigo              RO
# 56589               899    Fuori Regione / Provincia Autonoma             NaN
# 56590               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 56442        15425           ITF          ITF1         ITF11
# 56443        14628           ITF          ITF1         ITF12
# 56444        16879           ITF          ITF1         ITF13
# 56445        16291           ITF          ITF1         ITF14
# 56446          520           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 56586        61264           ITH          ITH3         ITH35
# 56587        71386           ITH          ITH3         ITH36
# 56588        12427           ITH          ITH3         ITH37
# 56589         4923           ITH          ITH3           NaN
# 56590          667           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 56293  2021-03-25T17:00:00              13               Abruzzo
# 56294  2021-03-25T17:00:00              13               Abruzzo
# 56295  2021-03-25T17:00:00              13               Abruzzo
# 56296  2021-03-25T17:00:00              13               Abruzzo
# 56297  2021-03-25T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 56437  2021-03-25T17:00:00               5                Veneto
# 56438  2021-03-25T17:00:00               5                Veneto
# 56439  2021-03-25T17:00:00               5                Veneto
# 56440  2021-03-25T17:00:00               5                Veneto
# 56441  2021-03-25T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 56293                66                              L'Aquila              AQ
# 56294                67                                Teramo              TE
# 56295                68                               Pescara              PE
# 56296                69                                Chieti              CH
# 56297               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 56437                27                               Venezia              VE
# 56438                28                                Padova              PD
# 56439                29                                Rovigo              RO
# 56440               899    Fuori Regione / Provincia Autonoma             NaN
# 56441               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 56293        15293           ITF          ITF1         ITF11
# 56294        14551           ITF          ITF1         ITF12
# 56295        16813           ITF          ITF1         ITF13
# 56296        16182           ITF          ITF1         ITF14
# 56297          512           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 56437        60759           ITH          ITH3         ITH35
# 56438        70960           ITH          ITH3         ITH36
# 56439        12326           ITH          ITH3         ITH37
# 56440         4940           ITH          ITH3           NaN
# 56441          654           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-03-26T17:00:00               1              Piemonte
# 1    2021-03-26T17:00:00               1              Piemonte
# 2    2021-03-26T17:00:00               1              Piemonte
# 3    2021-03-26T17:00:00               1              Piemonte
# 4    2021-03-26T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-03-26T17:00:00               9               Toscana
# 145  2021-03-26T17:00:00               4           P.A. Trento
# 146  2021-03-26T17:00:00              10                Umbria
# 147  2021-03-26T17:00:00               2         Valle d'Aosta
# 148  2021-03-26T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         160377           ITC          ITC1         ITC11
# 1          11386           ITC          ITC1         ITC12
# 2          23297           ITC          ITC1         ITC15
# 3          42000           ITC          ITC1         ITC16
# 4          14313           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          667           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-03-25T17:00:00               1              Piemonte
# 1    2021-03-25T17:00:00               1              Piemonte
# 2    2021-03-25T17:00:00               1              Piemonte
# 3    2021-03-25T17:00:00               1              Piemonte
# 4    2021-03-25T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-03-25T17:00:00               9               Toscana
# 145  2021-03-25T17:00:00               4           P.A. Trento
# 146  2021-03-25T17:00:00              10                Umbria
# 147  2021-03-25T17:00:00               2         Valle d'Aosta
# 148  2021-03-25T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         159180           ITC          ITC1         ITC11
# 1          11289           ITC          ITC1         ITC12
# 2          23122           ITC          ITC1         ITC15
# 3          41581           ITC          ITC1         ITC16
# 4          14247           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          654           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-03-26T17:00:00               1              Piemonte
# 1    2021-03-26T17:00:00               1              Piemonte
# 2    2021-03-26T17:00:00               1              Piemonte
# 3    2021-03-26T17:00:00               1              Piemonte
# 4    2021-03-26T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-03-26T17:00:00               9               Toscana
# 145  2021-03-26T17:00:00               4           P.A. Trento
# 146  2021-03-26T17:00:00              10                Umbria
# 147  2021-03-26T17:00:00               2         Valle d'Aosta
# 148  2021-03-26T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         160377           ITC          ITC1         ITC11
# 1          11386           ITC          ITC1         ITC12
# 2          23297           ITC          ITC1         ITC15
# 3          42000           ITC          ITC1         ITC16
# 4          14313           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          667           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                      1197
# 1                        97
# 2                       175
# 3                       419
# 4                        66
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                       0
# 148                      13
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
