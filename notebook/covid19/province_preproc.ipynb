# %%
import sys
import time
import requests
import datetime
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv'
csv_out_name = f'{path_csv}/covid19-{level}.csv'

# %%
url_cum = F.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
list(df_raw_p.columns)
# Out:
# ['data',
#  'stato',
#  'codice_regione',
#  'denominazione_regione',
#  'codice_provincia',
#  'denominazione_provincia',
#  'sigla_provincia',
#  'lat',
#  'long',
#  'totale_casi',
#  'note',
#  'codice_nuts_1',
#  'codice_nuts_2',
#  'codice_nuts_3']

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 97710  2021-12-27T17:00:00               5                Veneto
# 97711  2021-12-27T17:00:00               5                Veneto
# 97712  2021-12-27T17:00:00               5                Veneto
# 97713  2021-12-27T17:00:00               5                Veneto
# 97714  2021-12-27T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 97710                27                               Venezia              VE
# 97711                28                                Padova              PD
# 97712                29                                Rovigo              RO
# 97713               899    Fuori Regione / Provincia Autonoma             NaN
# 97714               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 97710       101425           ITH          ITH3         ITH35
# 97711       120152           ITH          ITH3         ITH36
# 97712        20591           ITH          ITH3         ITH37
# 97713         7051           ITH          ITH3           NaN
# 97714         2124           ITH          ITH3           NaN
#
# [97715 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = F.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-12-27', '2021-12-26')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 97566  2021-12-27T17:00:00              13               Abruzzo
# 97567  2021-12-27T17:00:00              13               Abruzzo
# 97568  2021-12-27T17:00:00              13               Abruzzo
# 97569  2021-12-27T17:00:00              13               Abruzzo
# 97570  2021-12-27T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 97710  2021-12-27T17:00:00               5                Veneto
# 97711  2021-12-27T17:00:00               5                Veneto
# 97712  2021-12-27T17:00:00               5                Veneto
# 97713  2021-12-27T17:00:00               5                Veneto
# 97714  2021-12-27T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 97566                66                              L'Aquila              AQ
# 97567                67                                Teramo              TE
# 97568                68                               Pescara              PE
# 97569                69                                Chieti              CH
# 97570               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 97710                27                               Venezia              VE
# 97711                28                                Padova              PD
# 97712                29                                Rovigo              RO
# 97713               899    Fuori Regione / Provincia Autonoma             NaN
# 97714               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 97566        24002           ITF          ITF1         ITF11
# 97567        24394           ITF          ITF1         ITF12
# 97568        23039           ITF          ITF1         ITF13
# 97569        24621           ITF          ITF1         ITF14
# 97570          786           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 97710       101425           ITH          ITH3         ITH35
# 97711       120152           ITH          ITH3         ITH36
# 97712        20591           ITH          ITH3         ITH37
# 97713         7051           ITH          ITH3           NaN
# 97714         2124           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 97417  2021-12-26T17:00:00              13               Abruzzo
# 97418  2021-12-26T17:00:00              13               Abruzzo
# 97419  2021-12-26T17:00:00              13               Abruzzo
# 97420  2021-12-26T17:00:00              13               Abruzzo
# 97421  2021-12-26T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 97561  2021-12-26T17:00:00               5                Veneto
# 97562  2021-12-26T17:00:00               5                Veneto
# 97563  2021-12-26T17:00:00               5                Veneto
# 97564  2021-12-26T17:00:00               5                Veneto
# 97565  2021-12-26T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 97417                66                              L'Aquila              AQ
# 97418                67                                Teramo              TE
# 97419                68                               Pescara              PE
# 97420                69                                Chieti              CH
# 97421               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 97561                27                               Venezia              VE
# 97562                28                                Padova              PD
# 97563                29                                Rovigo              RO
# 97564               899    Fuori Regione / Provincia Autonoma             NaN
# 97565               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 97417        23941           ITF          ITF1         ITF11
# 97418        24369           ITF          ITF1         ITF12
# 97419        22973           ITF          ITF1         ITF13
# 97420        24375           ITF          ITF1         ITF14
# 97421          786           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 97561       101031           ITH          ITH3         ITH35
# 97562       119505           ITH          ITH3         ITH36
# 97563        20467           ITH          ITH3         ITH37
# 97564         7012           ITH          ITH3           NaN
# 97565         2119           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-12-27T17:00:00               1              Piemonte
# 1    2021-12-27T17:00:00               1              Piemonte
# 2    2021-12-27T17:00:00               1              Piemonte
# 3    2021-12-27T17:00:00               1              Piemonte
# 4    2021-12-27T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-12-27T17:00:00               9               Toscana
# 145  2021-12-27T17:00:00               4           P.A. Trento
# 146  2021-12-27T17:00:00              10                Umbria
# 147  2021-12-27T17:00:00               2         Valle d'Aosta
# 148  2021-12-27T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         241283           ITC          ITC1         ITC11
# 1          16021           ITC          ITC1         ITC12
# 2          35141           ITC          ITC1         ITC15
# 3          64286           ITC          ITC1         ITC16
# 4          21789           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147           25           ITC          ITC2           NaN
# 148         2124           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-12-26T17:00:00               1              Piemonte
# 1    2021-12-26T17:00:00               1              Piemonte
# 2    2021-12-26T17:00:00               1              Piemonte
# 3    2021-12-26T17:00:00               1              Piemonte
# 4    2021-12-26T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-12-26T17:00:00               9               Toscana
# 145  2021-12-26T17:00:00               4           P.A. Trento
# 146  2021-12-26T17:00:00              10                Umbria
# 147  2021-12-26T17:00:00               2         Valle d'Aosta
# 148  2021-12-26T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         239210           ITC          ITC1         ITC11
# 1          15900           ITC          ITC1         ITC12
# 2          34786           ITC          ITC1         ITC15
# 3          63678           ITC          ITC1         ITC16
# 4          21565           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147           13           ITC          ITC2           NaN
# 148         2119           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-12-27T17:00:00               1              Piemonte
# 1    2021-12-27T17:00:00               1              Piemonte
# 2    2021-12-27T17:00:00               1              Piemonte
# 3    2021-12-27T17:00:00               1              Piemonte
# 4    2021-12-27T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-12-27T17:00:00               9               Toscana
# 145  2021-12-27T17:00:00               4           P.A. Trento
# 146  2021-12-27T17:00:00              10                Umbria
# 147  2021-12-27T17:00:00               2         Valle d'Aosta
# 148  2021-12-27T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         241283           ITC          ITC1         ITC11
# 1          16021           ITC          ITC1         ITC12
# 2          35141           ITC          ITC1         ITC15
# 3          64286           ITC          ITC1         ITC16
# 4          21789           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147           25           ITC          ITC2           NaN
# 148         2124           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                      2073
# 1                       121
# 2                       355
# 3                       608
# 4                       224
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                      12
# 148                       5
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
