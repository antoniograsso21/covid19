# %%
import sys
import time
import requests
import datetime
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv'
csv_out_name = f'{path_csv}/covid19-{level}.csv'

# %%
url_cum = F.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
list(df_raw_p.columns)
# Out:
# ['data',
#  'stato',
#  'codice_regione',
#  'denominazione_regione',
#  'codice_provincia',
#  'denominazione_provincia',
#  'sigla_provincia',
#  'lat',
#  'long',
#  'totale_casi',
#  'note',
#  'codice_nuts_1',
#  'codice_nuts_2',
#  'codice_nuts_3']

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                        data  codice_regione denominazione_regione  \
# 0       2020-02-24T18:00:00              13               Abruzzo
# 1       2020-02-24T18:00:00              13               Abruzzo
# 2       2020-02-24T18:00:00              13               Abruzzo
# 3       2020-02-24T18:00:00              13               Abruzzo
# 4       2020-02-24T18:00:00              13               Abruzzo
# ...                     ...             ...                   ...
# 117080  2022-05-06T17:00:00               5                Veneto
# 117081  2022-05-06T17:00:00               5                Veneto
# 117082  2022-05-06T17:00:00               5                Veneto
# 117083  2022-05-06T17:00:00               5                Veneto
# 117084  2022-05-06T17:00:00               5                Veneto
#
#         codice_provincia               denominazione_provincia  \
# 0                     66                              L'Aquila
# 1                     67                                Teramo
# 2                     68                               Pescara
# 3                     69                                Chieti
# 4                    979  In fase di definizione/aggiornamento
# ...                  ...                                   ...
# 117080                27                               Venezia
# 117081                28                                Padova
# 117082                29                                Rovigo
# 117083               899    Fuori Regione / Provincia Autonoma
# 117084               999  In fase di definizione/aggiornamento
#
#        sigla_provincia  totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                   AQ            0           NaN           NaN           NaN
# 1                   TE            0           NaN           NaN           NaN
# 2                   PE            0           NaN           NaN           NaN
# 3                   CH            0           NaN           NaN           NaN
# 4                  NaN            0           NaN           NaN           NaN
# ...                ...          ...           ...           ...           ...
# 117080              VE       281386           ITH          ITH3         ITH35
# 117081              PD       328239           ITH          ITH3         ITH36
# 117082              RO        70698           ITH          ITH3         ITH37
# 117083             NaN        26386           ITH          ITH3           NaN
# 117084             NaN         7198           ITH          ITH3           NaN
#
# [117085 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = F.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2022-05-06', '2022-05-05')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                        data  codice_regione denominazione_regione  \
# 116936  2022-05-06T17:00:00              13               Abruzzo
# 116937  2022-05-06T17:00:00              13               Abruzzo
# 116938  2022-05-06T17:00:00              13               Abruzzo
# 116939  2022-05-06T17:00:00              13               Abruzzo
# 116940  2022-05-06T17:00:00              13               Abruzzo
# ...                     ...             ...                   ...
# 117080  2022-05-06T17:00:00               5                Veneto
# 117081  2022-05-06T17:00:00               5                Veneto
# 117082  2022-05-06T17:00:00               5                Veneto
# 117083  2022-05-06T17:00:00               5                Veneto
# 117084  2022-05-06T17:00:00               5                Veneto
#
#         codice_provincia               denominazione_provincia  \
# 116936                66                              L'Aquila
# 116937                67                                Teramo
# 116938                68                               Pescara
# 116939                69                                Chieti
# 116940               879    Fuori Regione / Provincia Autonoma
# ...                  ...                                   ...
# 117080                27                               Venezia
# 117081                28                                Padova
# 117082                29                                Rovigo
# 117083               899    Fuori Regione / Provincia Autonoma
# 117084               999  In fase di definizione/aggiornamento
#
#        sigla_provincia  totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 116936              AQ        80167           ITF          ITF1         ITF11
# 116937              TE        95300           ITF          ITF1         ITF12
# 116938              PE        88534           ITF          ITF1         ITF13
# 116939              CH       108312           ITF          ITF1         ITF14
# 116940             NaN         7675           ITF          ITF1           NaN
# ...                ...          ...           ...           ...           ...
# 117080              VE       281386           ITH          ITH3         ITH35
# 117081              PD       328239           ITH          ITH3         ITH36
# 117082              RO        70698           ITH          ITH3         ITH37
# 117083             NaN        26386           ITH          ITH3           NaN
# 117084             NaN         7198           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                        data  codice_regione denominazione_regione  \
# 116787  2022-05-05T17:00:00              13               Abruzzo
# 116788  2022-05-05T17:00:00              13               Abruzzo
# 116789  2022-05-05T17:00:00              13               Abruzzo
# 116790  2022-05-05T17:00:00              13               Abruzzo
# 116791  2022-05-05T17:00:00              13               Abruzzo
# ...                     ...             ...                   ...
# 116931  2022-05-05T17:00:00               5                Veneto
# 116932  2022-05-05T17:00:00               5                Veneto
# 116933  2022-05-05T17:00:00               5                Veneto
# 116934  2022-05-05T17:00:00               5                Veneto
# 116935  2022-05-05T17:00:00               5                Veneto
#
#         codice_provincia               denominazione_provincia  \
# 116787                66                              L'Aquila
# 116788                67                                Teramo
# 116789                68                               Pescara
# 116790                69                                Chieti
# 116791               879    Fuori Regione / Provincia Autonoma
# ...                  ...                                   ...
# 116931                27                               Venezia
# 116932                28                                Padova
# 116933                29                                Rovigo
# 116934               899    Fuori Regione / Provincia Autonoma
# 116935               999  In fase di definizione/aggiornamento
#
#        sigla_provincia  totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 116787              AQ        79911           ITF          ITF1         ITF11
# 116788              TE        94887           ITF          ITF1         ITF12
# 116789              PE        88129           ITF          ITF1         ITF13
# 116790              CH       107818           ITF          ITF1         ITF14
# 116791             NaN         7660           ITF          ITF1           NaN
# ...                ...          ...           ...           ...           ...
# 116931              VE       280675           ITH          ITH3         ITH35
# 116932              PD       327285           ITH          ITH3         ITH36
# 116933              RO        70478           ITH          ITH3         ITH37
# 116934             NaN        26334           ITH          ITH3           NaN
# 116935             NaN         7178           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-05-06T17:00:00               1              Piemonte
# 1    2022-05-06T17:00:00               1              Piemonte
# 2    2022-05-06T17:00:00               1              Piemonte
# 3    2022-05-06T17:00:00               1              Piemonte
# 4    2022-05-06T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-05-06T17:00:00               9               Toscana
# 145  2022-05-06T17:00:00               4           P.A. Trento
# 146  2022-05-06T17:00:00              10                Umbria
# 147  2022-05-06T17:00:00               2         Valle d'Aosta
# 148  2022-05-06T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         613372           ITC          ITC1         ITC11
# 1          41290           ITC          ITC1         ITC12
# 2          86771           ITC          ITC1         ITC15
# 3         148798           ITC          ITC1         ITC16
# 4          54829           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147          128           ITC          ITC2           NaN
# 148         7198           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-05-05T17:00:00               1              Piemonte
# 1    2022-05-05T17:00:00               1              Piemonte
# 2    2022-05-05T17:00:00               1              Piemonte
# 3    2022-05-05T17:00:00               1              Piemonte
# 4    2022-05-05T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-05-05T17:00:00               9               Toscana
# 145  2022-05-05T17:00:00               4           P.A. Trento
# 146  2022-05-05T17:00:00              10                Umbria
# 147  2022-05-05T17:00:00               2         Valle d'Aosta
# 148  2022-05-05T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         612101           ITC          ITC1         ITC11
# 1          41177           ITC          ITC1         ITC12
# 2          86616           ITC          ITC1         ITC15
# 3         148485           ITC          ITC1         ITC16
# 4          54705           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147          128           ITC          ITC2           NaN
# 148         7178           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-05-06T17:00:00               1              Piemonte
# 1    2022-05-06T17:00:00               1              Piemonte
# 2    2022-05-06T17:00:00               1              Piemonte
# 3    2022-05-06T17:00:00               1              Piemonte
# 4    2022-05-06T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-05-06T17:00:00               9               Toscana
# 145  2022-05-06T17:00:00               4           P.A. Trento
# 146  2022-05-06T17:00:00              10                Umbria
# 147  2022-05-06T17:00:00               2         Valle d'Aosta
# 148  2022-05-06T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         613372           ITC          ITC1         ITC11
# 1          41290           ITC          ITC1         ITC12
# 2          86771           ITC          ITC1         ITC15
# 3         148798           ITC          ITC1         ITC16
# 4          54829           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147          128           ITC          ITC2           NaN
# 148         7198           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                      1271
# 1                       113
# 2                       155
# 3                       313
# 4                       124
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                       0
# 148                      20
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
