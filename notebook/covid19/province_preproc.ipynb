# %%
import sys
import time
import requests
import datetime
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv'
csv_out_name = f'{path_csv}/covid19-{level}.csv'

# %%
url_cum = F.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
list(df_raw_p.columns)
# Out:
# ['data',
#  'stato',
#  'codice_regione',
#  'denominazione_regione',
#  'codice_provincia',
#  'denominazione_provincia',
#  'sigla_provincia',
#  'lat',
#  'long',
#  'totale_casi',
#  'note',
#  'codice_nuts_1',
#  'codice_nuts_2',
#  'codice_nuts_3']

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 55245  2021-03-17T17:00:00               5                Veneto
# 55246  2021-03-17T17:00:00               5                Veneto
# 55247  2021-03-17T17:00:00               5                Veneto
# 55248  2021-03-17T17:00:00               5                Veneto
# 55249  2021-03-17T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 55245                27                               Venezia              VE
# 55246                28                                Padova              PD
# 55247                29                                Rovigo              RO
# 55248               899    Fuori Regione / Provincia Autonoma             NaN
# 55249               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 55245        58250           ITH          ITH3         ITH35
# 55246        67927           ITH          ITH3         ITH36
# 55247        11736           ITH          ITH3         ITH37
# 55248         4762           ITH          ITH3           NaN
# 55249          624           ITH          ITH3           NaN
#
# [55250 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = F.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2021-03-17', '2021-03-16')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 55101  2021-03-17T17:00:00              13               Abruzzo
# 55102  2021-03-17T17:00:00              13               Abruzzo
# 55103  2021-03-17T17:00:00              13               Abruzzo
# 55104  2021-03-17T17:00:00              13               Abruzzo
# 55105  2021-03-17T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 55245  2021-03-17T17:00:00               5                Veneto
# 55246  2021-03-17T17:00:00               5                Veneto
# 55247  2021-03-17T17:00:00               5                Veneto
# 55248  2021-03-17T17:00:00               5                Veneto
# 55249  2021-03-17T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 55101                66                              L'Aquila              AQ
# 55102                67                                Teramo              TE
# 55103                68                               Pescara              PE
# 55104                69                                Chieti              CH
# 55105               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 55245                27                               Venezia              VE
# 55246                28                                Padova              PD
# 55247                29                                Rovigo              RO
# 55248               899    Fuori Regione / Provincia Autonoma             NaN
# 55249               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 55101        14546           ITF          ITF1         ITF11
# 55102        14029           ITF          ITF1         ITF12
# 55103        16195           ITF          ITF1         ITF13
# 55104        15456           ITF          ITF1         ITF14
# 55105          489           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 55245        58250           ITH          ITH3         ITH35
# 55246        67927           ITH          ITH3         ITH36
# 55247        11736           ITH          ITH3         ITH37
# 55248         4762           ITH          ITH3           NaN
# 55249          624           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 54952  2021-03-16T17:00:00              13               Abruzzo
# 54953  2021-03-16T17:00:00              13               Abruzzo
# 54954  2021-03-16T17:00:00              13               Abruzzo
# 54955  2021-03-16T17:00:00              13               Abruzzo
# 54956  2021-03-16T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 55096  2021-03-16T17:00:00               5                Veneto
# 55097  2021-03-16T17:00:00               5                Veneto
# 55098  2021-03-16T17:00:00               5                Veneto
# 55099  2021-03-16T17:00:00               5                Veneto
# 55100  2021-03-16T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 54952                66                              L'Aquila              AQ
# 54953                67                                Teramo              TE
# 54954                68                               Pescara              PE
# 54955                69                                Chieti              CH
# 54956               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 55096                27                               Venezia              VE
# 55097                28                                Padova              PD
# 55098                29                                Rovigo              RO
# 55099               899    Fuori Regione / Provincia Autonoma             NaN
# 55100               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 54952        14454           ITF          ITF1         ITF11
# 54953        13999           ITF          ITF1         ITF12
# 54954        16113           ITF          ITF1         ITF13
# 54955        15382           ITF          ITF1         ITF14
# 54956          490           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 55096        57877           ITH          ITH3         ITH35
# 55097        67538           ITH          ITH3         ITH36
# 55098        11627           ITH          ITH3         ITH37
# 55099         4751           ITH          ITH3           NaN
# 55100          627           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-03-17T17:00:00               1              Piemonte
# 1    2021-03-17T17:00:00               1              Piemonte
# 2    2021-03-17T17:00:00               1              Piemonte
# 3    2021-03-17T17:00:00               1              Piemonte
# 4    2021-03-17T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-03-17T17:00:00               9               Toscana
# 145  2021-03-17T17:00:00               4           P.A. Trento
# 146  2021-03-17T17:00:00              10                Umbria
# 147  2021-03-17T17:00:00               2         Valle d'Aosta
# 148  2021-03-17T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         149462           ITC          ITC1         ITC11
# 1          10482           ITC          ITC1         ITC12
# 2          21700           ITC          ITC1         ITC15
# 3          38516           ITC          ITC1         ITC16
# 4          13548           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          624           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-03-16T17:00:00               1              Piemonte
# 1    2021-03-16T17:00:00               1              Piemonte
# 2    2021-03-16T17:00:00               1              Piemonte
# 3    2021-03-16T17:00:00               1              Piemonte
# 4    2021-03-16T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-03-16T17:00:00               9               Toscana
# 145  2021-03-16T17:00:00               4           P.A. Trento
# 146  2021-03-16T17:00:00              10                Umbria
# 147  2021-03-16T17:00:00               2         Valle d'Aosta
# 148  2021-03-16T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         148190           ITC          ITC1         ITC11
# 1          10398           ITC          ITC1         ITC12
# 2          21506           ITC          ITC1         ITC15
# 3          38078           ITC          ITC1         ITC16
# 4          13453           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          627           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2021-03-17T17:00:00               1              Piemonte
# 1    2021-03-17T17:00:00               1              Piemonte
# 2    2021-03-17T17:00:00               1              Piemonte
# 3    2021-03-17T17:00:00               1              Piemonte
# 4    2021-03-17T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2021-03-17T17:00:00               9               Toscana
# 145  2021-03-17T17:00:00               4           P.A. Trento
# 146  2021-03-17T17:00:00              10                Umbria
# 147  2021-03-17T17:00:00               2         Valle d'Aosta
# 148  2021-03-17T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         149462           ITC          ITC1         ITC11
# 1          10482           ITC          ITC1         ITC12
# 2          21700           ITC          ITC1         ITC15
# 3          38516           ITC          ITC1         ITC16
# 4          13548           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147            9           ITC          ITC2           NaN
# 148          624           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                      1272
# 1                        84
# 2                       194
# 3                       438
# 4                        95
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                       0
# 148                      -3
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
