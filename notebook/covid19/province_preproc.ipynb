# %%
import sys
import time
import requests
import datetime
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv'
csv_out_name = f'{path_csv}/covid19-{level}.csv'

# %%
url_cum = F.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
list(df_raw_p.columns)
# Out:
# ['data',
#  'stato',
#  'codice_regione',
#  'denominazione_regione',
#  'codice_provincia',
#  'denominazione_provincia',
#  'sigla_provincia',
#  'lat',
#  'long',
#  'totale_casi',
#  'note',
#  'codice_nuts_1',
#  'codice_nuts_2',
#  'codice_nuts_3']

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                       data  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00              13               Abruzzo
# 1      2020-02-24T18:00:00              13               Abruzzo
# 2      2020-02-24T18:00:00              13               Abruzzo
# 3      2020-02-24T18:00:00              13               Abruzzo
# 4      2020-02-24T18:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 98604  2022-01-02T17:00:00               5                Veneto
# 98605  2022-01-02T17:00:00               5                Veneto
# 98606  2022-01-02T17:00:00               5                Veneto
# 98607  2022-01-02T17:00:00               5                Veneto
# 98608  2022-01-02T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 0                    66                              L'Aquila              AQ
# 1                    67                                Teramo              TE
# 2                    68                               Pescara              PE
# 3                    69                                Chieti              CH
# 4                   979  In fase di definizione/aggiornamento             NaN
# ...                 ...                                   ...             ...
# 98604                27                               Venezia              VE
# 98605                28                                Padova              PD
# 98606                29                                Rovigo              RO
# 98607               899    Fuori Regione / Provincia Autonoma             NaN
# 98608               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                0           NaN           NaN           NaN
# 1                0           NaN           NaN           NaN
# 2                0           NaN           NaN           NaN
# 3                0           NaN           NaN           NaN
# 4                0           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 98604       110820           ITH          ITH3         ITH35
# 98605       129465           ITH          ITH3         ITH36
# 98606        22919           ITH          ITH3         ITH37
# 98607         8078           ITH          ITH3           NaN
# 98608         3071           ITH          ITH3           NaN
#
# [98609 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = F.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2022-01-02', '2022-01-01')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                       data  codice_regione denominazione_regione  \
# 98460  2022-01-02T17:00:00              13               Abruzzo
# 98461  2022-01-02T17:00:00              13               Abruzzo
# 98462  2022-01-02T17:00:00              13               Abruzzo
# 98463  2022-01-02T17:00:00              13               Abruzzo
# 98464  2022-01-02T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 98604  2022-01-02T17:00:00               5                Veneto
# 98605  2022-01-02T17:00:00               5                Veneto
# 98606  2022-01-02T17:00:00               5                Veneto
# 98607  2022-01-02T17:00:00               5                Veneto
# 98608  2022-01-02T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 98460                66                              L'Aquila              AQ
# 98461                67                                Teramo              TE
# 98462                68                               Pescara              PE
# 98463                69                                Chieti              CH
# 98464               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 98604                27                               Venezia              VE
# 98605                28                                Padova              PD
# 98606                29                                Rovigo              RO
# 98607               899    Fuori Regione / Provincia Autonoma             NaN
# 98608               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 98460        26350           ITF          ITF1         ITF11
# 98461        27965           ITF          ITF1         ITF12
# 98462        26969           ITF          ITF1         ITF13
# 98463        28667           ITF          ITF1         ITF14
# 98464         1148           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 98604       110820           ITH          ITH3         ITH35
# 98605       129465           ITH          ITH3         ITH36
# 98606        22919           ITH          ITH3         ITH37
# 98607         8078           ITH          ITH3           NaN
# 98608         3071           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                       data  codice_regione denominazione_regione  \
# 98311  2022-01-01T17:00:00              13               Abruzzo
# 98312  2022-01-01T17:00:00              13               Abruzzo
# 98313  2022-01-01T17:00:00              13               Abruzzo
# 98314  2022-01-01T17:00:00              13               Abruzzo
# 98315  2022-01-01T17:00:00              13               Abruzzo
# ...                    ...             ...                   ...
# 98455  2022-01-01T17:00:00               5                Veneto
# 98456  2022-01-01T17:00:00               5                Veneto
# 98457  2022-01-01T17:00:00               5                Veneto
# 98458  2022-01-01T17:00:00               5                Veneto
# 98459  2022-01-01T17:00:00               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 98311                66                              L'Aquila              AQ
# 98312                67                                Teramo              TE
# 98313                68                               Pescara              PE
# 98314                69                                Chieti              CH
# 98315               879    Fuori Regione / Provincia Autonoma             NaN
# ...                 ...                                   ...             ...
# 98455                27                               Venezia              VE
# 98456                28                                Padova              PD
# 98457                29                                Rovigo              RO
# 98458               899    Fuori Regione / Provincia Autonoma             NaN
# 98459               999  In fase di definizione/aggiornamento             NaN
#
#        totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 98311        26252           ITF          ITF1         ITF11
# 98312        27409           ITF          ITF1         ITF12
# 98313        26768           ITF          ITF1         ITF13
# 98314        28441           ITF          ITF1         ITF14
# 98315         1122           ITF          ITF1           NaN
# ...            ...           ...           ...           ...
# 98455       109848           ITH          ITH3         ITH35
# 98456       129134           ITH          ITH3         ITH36
# 98457        22707           ITH          ITH3         ITH37
# 98458         7911           ITH          ITH3           NaN
# 98459         3138           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-01-02T17:00:00               1              Piemonte
# 1    2022-01-02T17:00:00               1              Piemonte
# 2    2022-01-02T17:00:00               1              Piemonte
# 3    2022-01-02T17:00:00               1              Piemonte
# 4    2022-01-02T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-01-02T17:00:00               9               Toscana
# 145  2022-01-02T17:00:00               4           P.A. Trento
# 146  2022-01-02T17:00:00              10                Umbria
# 147  2022-01-02T17:00:00               2         Valle d'Aosta
# 148  2022-01-02T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         264517           ITC          ITC1         ITC11
# 1          17509           ITC          ITC1         ITC12
# 2          39351           ITC          ITC1         ITC15
# 3          71399           ITC          ITC1         ITC16
# 4          24088           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147           70           ITC          ITC2           NaN
# 148         3071           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-01-01T17:00:00               1              Piemonte
# 1    2022-01-01T17:00:00               1              Piemonte
# 2    2022-01-01T17:00:00               1              Piemonte
# 3    2022-01-01T17:00:00               1              Piemonte
# 4    2022-01-01T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-01-01T17:00:00               9               Toscana
# 145  2022-01-01T17:00:00               4           P.A. Trento
# 146  2022-01-01T17:00:00              10                Umbria
# 147  2022-01-01T17:00:00               2         Valle d'Aosta
# 148  2022-01-01T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         263272           ITC          ITC1         ITC11
# 1          17421           ITC          ITC1         ITC12
# 2          39212           ITC          ITC1         ITC15
# 3          71121           ITC          ITC1         ITC16
# 4          23945           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147          172           ITC          ITC2           NaN
# 148         3138           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-01-02T17:00:00               1              Piemonte
# 1    2022-01-02T17:00:00               1              Piemonte
# 2    2022-01-02T17:00:00               1              Piemonte
# 3    2022-01-02T17:00:00               1              Piemonte
# 4    2022-01-02T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-01-02T17:00:00               9               Toscana
# 145  2022-01-02T17:00:00               4           P.A. Trento
# 146  2022-01-02T17:00:00              10                Umbria
# 147  2022-01-02T17:00:00               2         Valle d'Aosta
# 148  2022-01-02T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         264517           ITC          ITC1         ITC11
# 1          17509           ITC          ITC1         ITC12
# 2          39351           ITC          ITC1         ITC15
# 3          71399           ITC          ITC1         ITC16
# 4          24088           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147           70           ITC          ITC2           NaN
# 148         3071           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                      1245
# 1                        88
# 2                       139
# 3                       278
# 4                       143
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                    -102
# 148                     -67
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
