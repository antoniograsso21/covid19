# %%
import sys
import time
import requests
import datetime
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F

# Disable warning
pd.options.mode.chained_assignment = None

level = 'province'

path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv'
csv_out_name = f'{path_csv}/covid19-{level}.csv'

# %%
url_cum = F.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv'

# %%
df_raw_p = pd.read_csv(url_cum)
list(df_raw_p.columns)
# Out:
# ['data',
#  'stato',
#  'codice_regione',
#  'denominazione_regione',
#  'codice_provincia',
#  'denominazione_provincia',
#  'sigla_provincia',
#  'lat',
#  'long',
#  'totale_casi',
#  'note',
#  'codice_nuts_1',
#  'codice_nuts_2',
#  'codice_nuts_3']

# %%
cols_to_drop = ['stato', 'lat', 'long', 'note']
df_pd = df_raw_p.drop(cols_to_drop, axis=1)
df_pd
# Out:
#                        data  codice_regione denominazione_regione  \
# 0       2020-02-24T18:00:00              13               Abruzzo
# 1       2020-02-24T18:00:00              13               Abruzzo
# 2       2020-02-24T18:00:00              13               Abruzzo
# 3       2020-02-24T18:00:00              13               Abruzzo
# 4       2020-02-24T18:00:00              13               Abruzzo
# ...                     ...             ...                   ...
# 101435  2022-01-21T17:00:00               5                Veneto
# 101436  2022-01-21T17:00:00               5                Veneto
# 101437  2022-01-21T17:00:00               5                Veneto
# 101438  2022-01-21T17:00:00               5                Veneto
# 101439  2022-01-21T17:00:00               5                Veneto
#
#         codice_provincia               denominazione_provincia  \
# 0                     66                              L'Aquila
# 1                     67                                Teramo
# 2                     68                               Pescara
# 3                     69                                Chieti
# 4                    979  In fase di definizione/aggiornamento
# ...                  ...                                   ...
# 101435                27                               Venezia
# 101436                28                                Padova
# 101437                29                                Rovigo
# 101438               899    Fuori Regione / Provincia Autonoma
# 101439               999  In fase di definizione/aggiornamento
#
#        sigla_provincia  totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0                   AQ            0           NaN           NaN           NaN
# 1                   TE            0           NaN           NaN           NaN
# 2                   PE            0           NaN           NaN           NaN
# 3                   CH            0           NaN           NaN           NaN
# 4                  NaN            0           NaN           NaN           NaN
# ...                ...          ...           ...           ...           ...
# 101435              VE       155765           ITH          ITH3         ITH35
# 101436              PD       184231           ITH          ITH3         ITH36
# 101437              RO        39130           ITH          ITH3         ITH37
# 101438             NaN        14974           ITH          ITH3           NaN
# 101439             NaN         4871           ITH          ITH3           NaN
#
# [101440 rows x 10 columns]

# %%
last_date_str = df_pd.iloc[-1].data.split('T')[0]
last_date = datetime.datetime.strptime(last_date_str, '%Y-%m-%d')
prev_date = F.get_previous_date(last_date)
prev_date_str = datetime.datetime.strftime(prev_date, '%Y-%m-%d')
last_date_str, prev_date_str
# Out:
# ('2022-01-21', '2022-01-20')

# %%
df_raw_p_1 = df_pd[df_pd.data.str.startswith(last_date_str)]
df_raw_p_1
# Out:
#                        data  codice_regione denominazione_regione  \
# 101291  2022-01-21T17:00:00              13               Abruzzo
# 101292  2022-01-21T17:00:00              13               Abruzzo
# 101293  2022-01-21T17:00:00              13               Abruzzo
# 101294  2022-01-21T17:00:00              13               Abruzzo
# 101295  2022-01-21T17:00:00              13               Abruzzo
# ...                     ...             ...                   ...
# 101435  2022-01-21T17:00:00               5                Veneto
# 101436  2022-01-21T17:00:00               5                Veneto
# 101437  2022-01-21T17:00:00               5                Veneto
# 101438  2022-01-21T17:00:00               5                Veneto
# 101439  2022-01-21T17:00:00               5                Veneto
#
#         codice_provincia               denominazione_provincia  \
# 101291                66                              L'Aquila
# 101292                67                                Teramo
# 101293                68                               Pescara
# 101294                69                                Chieti
# 101295               879    Fuori Regione / Provincia Autonoma
# ...                  ...                                   ...
# 101435                27                               Venezia
# 101436                28                                Padova
# 101437                29                                Rovigo
# 101438               899    Fuori Regione / Provincia Autonoma
# 101439               999  In fase di definizione/aggiornamento
#
#        sigla_provincia  totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 101291              AQ        39206           ITF          ITF1         ITF11
# 101292              TE        46105           ITF          ITF1         ITF12
# 101293              PE        43851           ITF          ITF1         ITF13
# 101294              CH        50517           ITF          ITF1         ITF14
# 101295             NaN         2364           ITF          ITF1           NaN
# ...                ...          ...           ...           ...           ...
# 101435              VE       155765           ITH          ITH3         ITH35
# 101436              PD       184231           ITH          ITH3         ITH36
# 101437              RO        39130           ITH          ITH3         ITH37
# 101438             NaN        14974           ITH          ITH3           NaN
# 101439             NaN         4871           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_raw_p_0 = df_pd[df_pd.data.str.startswith(prev_date_str)]
df_raw_p_0
# Out:
#                        data  codice_regione denominazione_regione  \
# 101142  2022-01-20T17:00:00              13               Abruzzo
# 101143  2022-01-20T17:00:00              13               Abruzzo
# 101144  2022-01-20T17:00:00              13               Abruzzo
# 101145  2022-01-20T17:00:00              13               Abruzzo
# 101146  2022-01-20T17:00:00              13               Abruzzo
# ...                     ...             ...                   ...
# 101286  2022-01-20T17:00:00               5                Veneto
# 101287  2022-01-20T17:00:00               5                Veneto
# 101288  2022-01-20T17:00:00               5                Veneto
# 101289  2022-01-20T17:00:00               5                Veneto
# 101290  2022-01-20T17:00:00               5                Veneto
#
#         codice_provincia               denominazione_provincia  \
# 101142                66                              L'Aquila
# 101143                67                                Teramo
# 101144                68                               Pescara
# 101145                69                                Chieti
# 101146               879    Fuori Regione / Provincia Autonoma
# ...                  ...                                   ...
# 101286                27                               Venezia
# 101287                28                                Padova
# 101288                29                                Rovigo
# 101289               899    Fuori Regione / Provincia Autonoma
# 101290               999  In fase di definizione/aggiornamento
#
#        sigla_provincia  totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 101142              AQ        38482           ITF          ITF1         ITF11
# 101143              TE        45187           ITF          ITF1         ITF12
# 101144              PE        42988           ITF          ITF1         ITF13
# 101145              CH        49397           ITF          ITF1         ITF14
# 101146             NaN         2327           ITF          ITF1           NaN
# ...                ...          ...           ...           ...           ...
# 101286              VE       152958           ITH          ITH3         ITH35
# 101287              PD       180804           ITH          ITH3         ITH36
# 101288              RO        38300           ITH          ITH3         ITH37
# 101289             NaN        14718           ITH          ITH3           NaN
# 101290             NaN         4689           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S
df_raw_p_1 = df_raw_p_1.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_1
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-01-21T17:00:00               1              Piemonte
# 1    2022-01-21T17:00:00               1              Piemonte
# 2    2022-01-21T17:00:00               1              Piemonte
# 3    2022-01-21T17:00:00               1              Piemonte
# 4    2022-01-21T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-01-21T17:00:00               9               Toscana
# 145  2022-01-21T17:00:00               4           P.A. Trento
# 146  2022-01-21T17:00:00              10                Umbria
# 147  2022-01-21T17:00:00               2         Valle d'Aosta
# 148  2022-01-21T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         401452           ITC          ITC1         ITC11
# 1          27210           ITC          ITC1         ITC12
# 2          59990           ITC          ITC1         ITC15
# 3         107319           ITC          ITC1         ITC16
# 4          35533           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147          141           ITC          ITC2           NaN
# 148         4871           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
# State S - 1
df_raw_p_0 = df_raw_p_0.sort_values(by='codice_provincia').reset_index(drop=True)
df_raw_p_0
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-01-20T17:00:00               1              Piemonte
# 1    2022-01-20T17:00:00               1              Piemonte
# 2    2022-01-20T17:00:00               1              Piemonte
# 3    2022-01-20T17:00:00               1              Piemonte
# 4    2022-01-20T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-01-20T17:00:00               9               Toscana
# 145  2022-01-20T17:00:00               4           P.A. Trento
# 146  2022-01-20T17:00:00              10                Umbria
# 147  2022-01-20T17:00:00               2         Valle d'Aosta
# 148  2022-01-20T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0         393265           ITC          ITC1         ITC11
# 1          26649           ITC          ITC1         ITC12
# 2          58812           ITC          ITC1         ITC15
# 3         105590           ITC          ITC1         ITC16
# 4          34921           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147          245           ITC          ITC2           NaN
# 148         4689           ITH          ITH3           NaN
#
# [149 rows x 10 columns]

# %%
df_p = df_raw_p_1.copy()
df_p['variazione_totale_casi'] = df_raw_p_1['totale_casi'] - df_raw_p_0['totale_casi']
df_p
# Out:
#                     data  codice_regione denominazione_regione  \
# 0    2022-01-21T17:00:00               1              Piemonte
# 1    2022-01-21T17:00:00               1              Piemonte
# 2    2022-01-21T17:00:00               1              Piemonte
# 3    2022-01-21T17:00:00               1              Piemonte
# 4    2022-01-21T17:00:00               1              Piemonte
# ..                   ...             ...                   ...
# 144  2022-01-21T17:00:00               9               Toscana
# 145  2022-01-21T17:00:00               4           P.A. Trento
# 146  2022-01-21T17:00:00              10                Umbria
# 147  2022-01-21T17:00:00               2         Valle d'Aosta
# 148  2022-01-21T17:00:00               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# 0                   1                                Torino              TO
# 1                   2                              Vercelli              VC
# 2                   3                                Novara              NO
# 3                   4                                 Cuneo              CN
# 4                   5                                  Asti              AT
# ..                ...                                   ...             ...
# 144               995  In fase di definizione/aggiornamento             NaN
# 145               996  In fase di definizione/aggiornamento             NaN
# 146               997  In fase di definizione/aggiornamento             NaN
# 147               998  In fase di definizione/aggiornamento             NaN
# 148               999  In fase di definizione/aggiornamento             NaN
#
#      totale_casi codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 0         401452           ITC          ITC1         ITC11
# 1          27210           ITC          ITC1         ITC12
# 2          59990           ITC          ITC1         ITC15
# 3         107319           ITC          ITC1         ITC16
# 4          35533           ITC          ITC1         ITC17
# ..           ...           ...           ...           ...
# 144            0           ITI          ITI1           NaN
# 145            0           ITH          ITH2           NaN
# 146            0           ITI          ITI2           NaN
# 147          141           ITC          ITC2           NaN
# 148         4871           ITH          ITH3           NaN
#
#      variazione_totale_casi
# 0                      8187
# 1                       561
# 2                      1178
# 3                      1729
# 4                       612
# ..                      ...
# 144                       0
# 145                       0
# 146                       0
# 147                    -104
# 148                     182
#
# [149 rows x 11 columns]

# %%
# Write df to csv
df_p.to_csv(csv_out_name, index=False)
