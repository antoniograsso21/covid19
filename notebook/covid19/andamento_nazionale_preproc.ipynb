# %%
import sys
import datetime
import pandas as pd

path_root = '../..'
sys.path.append(f'{path_root}/')
from src.util.functions import Functions as F

# Disable warning
pd.options.mode.chained_assignment = None 

level = 'andamento-nazionale'

path_data = f'{path_root}/data'
path_csv = f'{path_data}/csv'
csv_out_name = f'{path_csv}/covid19-{level}.csv'

# %%
url_cum = F.get_url_cum(level)
url_cum
# Out:
# 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv'

# %%
df_n_raw = pd.read_csv(url_cum)
df_n_raw
# Out:
#                     data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24T18:00:00   ITA                     101                 26
# 1    2020-02-25T18:00:00   ITA                     114                 35
# 2    2020-02-26T18:00:00   ITA                     128                 36
# 3    2020-02-27T18:00:00   ITA                     248                 56
# 4    2020-02-28T18:00:00   ITA                     345                 64
# ..                   ...   ...                     ...                ...
# 383  2021-03-13T17:00:00   ITA                   24153               2982
# 384  2021-03-14T17:00:00   ITA                   24518               3082
# 385  2021-03-15T17:00:00   ITA                   25338               3157
# 386  2021-03-16T17:00:00   ITA                   26098               3256
# 387  2021-03-17T17:00:00   ITA                   26517               3317
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# ...

# %%
# Drop unused columns
df_nd = df_n_raw.drop(['stato', 'note', 'note_test', 'note_casi'], axis=1)
df_nd
# Out:
#                     data  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24T18:00:00                     101                 26
# 1    2020-02-25T18:00:00                     114                 35
# 2    2020-02-26T18:00:00                     128                 36
# 3    2020-02-27T18:00:00                     248                 56
# 4    2020-02-28T18:00:00                     345                 64
# ..                   ...                     ...                ...
# 383  2021-03-13T17:00:00                   24153               2982
# 384  2021-03-14T17:00:00                   24518               3082
# 385  2021-03-15T17:00:00                   25338               3157
# 386  2021-03-16T17:00:00                   26098               3256
# 387  2021-03-17T17:00:00                   26517               3317
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 0                     127                      94              221
# ...

# %%
list(df_nd.columns)
# Out:
# ['data',
#  'ricoverati_con_sintomi',
#  'terapia_intensiva',
#  'totale_ospedalizzati',
#  'isolamento_domiciliare',
#  'totale_positivi',
#  'variazione_totale_positivi',
#  'nuovi_positivi',
#  'dimessi_guariti',
#  'deceduti',
#  'casi_da_sospetto_diagnostico',
#  'casi_da_screening',
#  'totale_casi',
#  'tamponi',
#  'casi_testati',
#  'ingressi_terapia_intensiva',
#  'totale_positivi_test_molecolare',
#  'totale_positivi_test_antigenico_rapido',
#  'tamponi_test_molecolare',
#  'tamponi_test_antigenico_rapido']

# %%
# Add columns
df_nd['variazione_terapia_intensiva'] = df_nd['terapia_intensiva'].diff()
df_nd['variazione_ricoverati_con_sintomi'] = df_nd['ricoverati_con_sintomi'].diff()
df_nd['variazione_totale_ospedalizzati'] = df_nd['totale_ospedalizzati'].diff()
df_nd['variazione_isolamento_domiciliare'] = df_nd['isolamento_domiciliare'].diff()
df_nd['nuovi_dimessi_guariti'] = df_nd['dimessi_guariti'].diff()
df_nd['nuovi_deceduti'] = df_nd['deceduti'].diff()
df_nd['nuovi_tamponi'] = df_nd['tamponi'].diff()
df_nd['nuovi_casi_testati'] = df_nd['casi_testati'].diff()
df_nd
# Out:
#                     data  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24T18:00:00                     101                 26
# 1    2020-02-25T18:00:00                     114                 35
# 2    2020-02-26T18:00:00                     128                 36
# 3    2020-02-27T18:00:00                     248                 56
# 4    2020-02-28T18:00:00                     345                 64
# ..                   ...                     ...                ...
# 383  2021-03-13T17:00:00                   24153               2982
# 384  2021-03-14T17:00:00                   24518               3082
# 385  2021-03-15T17:00:00                   25338               3157
# 386  2021-03-16T17:00:00                   26098               3256
# 387  2021-03-17T17:00:00                   26517               3317
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 0                     127                      94              221
# ...

# %%
df_n = df_nd.iloc[1:]
df_n
# Out:
#                     data  ricoverati_con_sintomi  terapia_intensiva  \
# 1    2020-02-25T18:00:00                     114                 35
# 2    2020-02-26T18:00:00                     128                 36
# 3    2020-02-27T18:00:00                     248                 56
# 4    2020-02-28T18:00:00                     345                 64
# 5    2020-02-29T18:00:00                     401                105
# ..                   ...                     ...                ...
# 383  2021-03-13T17:00:00                   24153               2982
# 384  2021-03-14T17:00:00                   24518               3082
# 385  2021-03-15T17:00:00                   25338               3157
# 386  2021-03-16T17:00:00                   26098               3256
# 387  2021-03-17T17:00:00                   26517               3317
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 1                     150                     162              311
# ...

# %%
# Add columns
df_n['ti_su_to'] = ((df_n['terapia_intensiva'] / df_n['totale_ospedalizzati']) * 100).round(2)
df_n['to_su_tp'] = ((df_n['totale_ospedalizzati'] / df_n['totale_positivi']) * 100).round(2)
df_n['np_su_nt'] = ((df_n['nuovi_positivi'] / df_n['nuovi_tamponi']) * 100).round(2)
df_n['np_su_nct'] = ((df_n['nuovi_positivi'] / df_n['nuovi_casi_testati']) * 100).round(2)
df_n['var_ti_perc'] = ((df_n['variazione_terapia_intensiva'] / (df_n['terapia_intensiva'] - df_n['variazione_terapia_intensiva'])) * 100).round(2)
df_n['var_pos_perc'] = ((df_n['variazione_totale_positivi'] / (df_n['totale_positivi'] - df_n['variazione_totale_positivi'])) * 100).round(2)
df_n
# Out:
#                     data  ricoverati_con_sintomi  terapia_intensiva  \
# 1    2020-02-25T18:00:00                     114                 35
# 2    2020-02-26T18:00:00                     128                 36
# 3    2020-02-27T18:00:00                     248                 56
# 4    2020-02-28T18:00:00                     345                 64
# 5    2020-02-29T18:00:00                     401                105
# ..                   ...                     ...                ...
# 383  2021-03-13T17:00:00                   24153               2982
# 384  2021-03-14T17:00:00                   24518               3082
# 385  2021-03-15T17:00:00                   25338               3157
# 386  2021-03-16T17:00:00                   26098               3256
# 387  2021-03-17T17:00:00                   26517               3317
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 1                     150                     162              311
# ...

# %%
df_n.to_csv(csv_out_name, index=False)

# %%
df_n[['totale_positivi', 'var_pos_perc', 'variazione_totale_positivi']]
# df_n.columns
# Out:
#      totale_positivi  var_pos_perc  variazione_totale_positivi
# 1                311         40.72                          90
# 2                385         23.79                          74
# 3                588         52.73                         203
# 4                821         39.63                         233
# 5               1049         27.77                         228
# ..               ...           ...                         ...
# 383           520061          2.11                       10744
# 384           531266          2.15                       11205
# 385           530357         -0.17                        -909
# 386           536115          1.09                        5758
# 387           539008          0.54                        2893
#
# [387 rows x 3 columns]
